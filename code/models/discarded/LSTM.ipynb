# %%
import os
import pandas as pd
import numpy as np
test = pd.read_csv('./test/test.csv', encoding='CP949')
df23 = pd.read_csv('./data/train_subway23.csv', encoding='CP949')
df22 = pd.read_csv('./data/train_subway22.csv', encoding='CP949')
df21 = pd.read_csv('./data/train_subway21.csv', encoding='CP949')
df = pd.concat([df21, df22, df23], axis=0, ignore_index=True)
t = pd.read_excel('./data/환승역.xlsx', names =['Line','station_name','transfer'], header=0)
address = pd.read_csv('./data/result_address.csv', encoding='CP949')
subway_13 = pd.DataFrame({'역명':['성수E', '응암S','불암산']
             ,'주소':['서울 성동구 아차산로 100','서울 은평구 증산로 477','서울 노원구 상계로 305']})
address = pd.concat([address, subway_13], axis=0).reset_index(drop=True)
df.shape
# Out:
# (16369332, 15)

# %%
address.columns=['station_name','address']
address.station_name = address.station_name.apply(lambda x: x.split('(')[0].strip() if '(' in x else x)
address.address = address.address.apply(lambda x: x.split()[0] if '서울' not in x else x.split()[1])
addr = address['address']  
address['address'] = np.where(addr.str.contains('인천'), '인천',np.where(addr.str.contains('경기'), '경기', addr))

# %%
import os
import numpy as np
import pandas as pd
from pandas.api.types import CategoricalDtype
from holidayskr import year_holidays
from sklearn.preprocessing import MinMaxScaler, LabelEncoder
from sklearn.metrics import mean_squared_error, r2_score
from xgboost import XGBRegressor
import joblib
import warnings

warnings.filterwarnings('ignore')

def preprocessing(data, t, address, is_train=True, known_stations=None):
    data = data.copy()
    # 1)  → datetime
    data['TM'] = data['TM'].astype(str)
    data['TM'] = pd.to_datetime(data['TM'], format='%Y%m%d%H')

    # 2) 범주형 변환
    cat_columns = ['Line', 'station_number', 'STN', 'station_name', 'Direction']
    for col in cat_columns:
        data[col] = data[col].astype('category')

    # 3) 결측값 placeholder
    data['WD']     = data['WD'].where(data['WD'] >=   0, np.nan)
    data['WS']     = data['WS'].replace(-99.0,          np.nan)
    data['RN_DAY'] = data['RN_DAY'].replace(-99.0,      np.nan)
    data['RN_HR1'] = data['RN_HR1'].replace(-99.0,      np.nan)
    data['TA']     = data['TA'].replace(-99.0,          np.nan)
    data['ta_chi'] = data['ta_chi'].replace(-99.0,      np.nan)
    data['SI']     = data['SI'].replace(-99.0,          np.nan)
    data['HM']     = data['HM'].replace(-99.0,          np.nan)

    # 4) SI 이진 플래그
    data['SI'] = data['SI'].notna().astype(int)

    # 5) station_name 교정
    data['station_name'] = data['station_name'].astype(str).replace({
        '당고개': '불암산',
        '자양(뚝섬한강공원)': '자양',
        '신촌(지하)': '신촌'
    })
    # 6) 신설역 변수 생성
    new_station_list = {'구리', '다산', '동구릉', '별내', '암사역사공원', '장자호수공원'}
    known_stations = data['STN'].unique()
    # 컬럼명이 'station_name'이 아니라 '역명'이라면 df['역명'] 으로 바꿔 주세요.
    # 7) 신규관측소 변수
    if is_train:
        # 학습 데이터는 기준이 될 known_stations를 만들어 두고
        data['신설역'] = 0
        data['신규관측소'] = 0
        이상치_4호선_역명 = ['한대앞','중앙','고잔','초지','안산','신길온천','정왕','오이도']
        이상치_8호선_역명 = ['남위례']
        
        pattern_8 = '|'.join(이상치_8호선_역명)
        pattern_4 = '|'.join(이상치_4호선_역명)
        
        mask_8 = (data['Line'] == 8) & data['station_name'].str.contains(pattern_8) & (data['TM'] < '2021-12-18')
        mask_4 = (data['Line'] == 4) & data['station_name'].str.contains(pattern_4) & (data['TM'] <= '2022-06-13')
        print('train셋 공지사항 이상치 ',(data.shape[0] - data[~(mask_8 | mask_4)].reset_index(drop=True).shape[0])/data.shape[0],'% 제거')
        data = data[~(mask_8 | mask_4)].reset_index(drop=True)

    else:
        # test에서는 train에서 넘어온 known_stations를 이용해 플래그 처리
        data['신설역'] = data['station_name'].apply(lambda x: 0 if x in known_stations else 1)
        data['신규관측소'] = data['STN'].apply(lambda x: 0 if x in known_stations else 1)

    # 7 ) 선형 보간
    cols_to_interp = ['TA', 'WD', 'WS', 'RN_DAY', 'RN_HR1', 'ta_chi','HM']
    data[cols_to_interp] = data[cols_to_interp].interpolate(method='linear', limit_direction='both')
    data[cols_to_interp] = data[cols_to_interp].interpolate(method='linear', limit_direction='both')
    
    # 8) 외부 테이블 병합
    data = data.merge(t, on=['Line','station_name'], how='left')
    data['transfer'] = data['transfer'].fillna(0).astype(int)
    data = data.merge(address, on=['station_name'], how='left')

    # 9) 파생 변수
    data['year']         = data['TM'].dt.year - 2021
    data['month']        = data['TM'].dt.month
    data['day']          = data['TM'].dt.day
    data['hour']         = data['TM'].dt.hour
    data['weekday']      = data['TM'].dt.dayofweek
    data['week_of_month']= (data['day'] - 1) // 7 + 1
    data['week_of_year'] = data['TM'].dt.isocalendar().week.astype(int)
    data['day_of_year']  = data['TM'].dt.dayofyear

    # 10) 공휴일 플래그
    holidays = []
    for yr in [2021,2022,2023,2024]:
        holidays += [d for d,_ in year_holidays(yr)]
    data['is_holiday']            = data['TM'].dt.date.isin(holidays).astype(int)
    data['is_day_before_holiday'] = data['TM'].dt.date.shift(-1).isin(holidays).astype(int)
    data['is_day_after_holiday']  = data['TM'].dt.date.shift(1).isin(holidays).astype(int)

    # 11) 주말 플래그
    data['is_weekend'] = data['weekday'].isin([5,6]).astype(int)

    # 12) 시간대 범주
    data['time_period'] = np.where(data['hour'].isin([7,8,9]), '출근',
                             np.where(data['hour'].isin([17,18,19]), '퇴근',
                             np.where((data['hour']>9)&(data['hour']<17), '낮',
                             np.where((data['hour']>19)&(data['hour']<21), '저녁',
                             '밤'))))
    direction_order   = ['상선','하선','외선','내선']
    time_period_order = ['밤','출근','낮','저녁','퇴근']
    data['Direction']   = data['Direction'].astype(
        CategoricalDtype(categories=direction_order, ordered=True)
    ).cat.codes
    data['time_period'] = data['time_period'].astype(
        CategoricalDtype(categories=time_period_order, ordered=True)
    ).cat.codes

    # 13) 주기성 sin/cos (24h, 7d, 31d, 5w, 52w, 365d)
    data['sin_hod'] = np.sin(2*np.pi * data['hour']        / 24)
    data['cos_hod'] = np.cos(2*np.pi * data['hour']        / 24)
    data['sin_dow'] = np.sin(2*np.pi * data['weekday']     / 7)
    data['cos_dow'] = np.cos(2*np.pi * data['weekday']     / 7)
    data['sin_dom'] = np.sin(2*np.pi * data['day']         / 31)
    data['cos_dom'] = np.cos(2*np.pi * data['day']         / 31)
    data['sin_wom'] = np.sin(2*np.pi * data['week_of_month'] / 5)
    data['cos_wom'] = np.cos(2*np.pi * data['week_of_month'] / 5)
    data['sin_woy'] = np.sin(2*np.pi * data['week_of_year']  / 52)
    data['cos_woy'] = np.cos(2*np.pi * data['week_of_year']  / 52)
    data['sin_doy'] = np.sin(2*np.pi * data['day_of_year']   / 365)
    data['cos_doy'] = np.cos(2*np.pi * data['day_of_year']   / 365)

    # 14) 그룹별 보간 (key 단위)
    # cols_to_fill = ['WD','RN_DAY','RN_HR1','TA','ta_chi','SI','HM','WS']
    # data[cols_to_fill] = data.groupby('key')[cols_to_fill] \
    #                      .transform(lambda grp: grp.interpolate(method='linear', limit_direction='both'))
    # print('보간 후 남은 결측값:\n', data[cols_to_fill].isna().sum())
    # return data
    return data

# 전처리
df   = preprocessing(df,   t, address, is_train=True)
known_stations = df['STN'].unique()
test = preprocessing(test, t, address,
                               is_train=False,
                               known_stations=known_stations)

le_m = LabelEncoder()
le_d = LabelEncoder()
df['month'] = le_m.fit_transform(df['month'])
df['day'] = le_d.fit_transform(df['day'])
test['month'] = le_m.transform(test['month'])
test['day'] = le_d.transform(test['day'])

print('전처리 완료')

# feature / target 정의
ordered_cols = ['Direction', 'time_period']
cat_cols     = [
                'station_number'
                , 'address'
               # , 'station_name'
               ] + ordered_cols
num_cols = [
    'HM','RN_DAY','RN_HR1','SI','TA','WD','WS'
    ,'STN'
    ,'sin_dom','cos_dom','sin_dow','cos_dow','sin_hod','cos_hod'
    ,'sin_wom','cos_wom','sin_woy','cos_woy','sin_doy','cos_doy'
    ,'day','day_of_year','hour'
    ,'is_day_before_holiday','is_day_after_holiday','is_holiday','is_weekend'
    ,'month','transfer','week_of_month','week_of_year','weekday','year'
    ,'신설역', '신규관측소'
]
feature_cols = num_cols + ordered_cols + cat_cols
target_col   = 'Congestion'

results = []
final_results = []
print('완료')
# Out:
# train셋 공지사항 이상치  0.009340271185165039 % 제거
# 전처리 완료
# 완료

# %% [markdown]
# - 메모리 효율화

# %%
del df23
del df22
del df21
del t
del address

# %% [markdown]
# # ET

# %%
import os
import time
import gc
import numpy as np
import pandas as pd
import joblib
from tqdm import tqdm
from sklearn.preprocessing import MinMaxScaler
from sklearn.metrics import mean_squared_error, r2_score
from sklearn.ensemble import ExtraTreesRegressor

def evaluate_model(name, model, line, X_train, y_train, X_val, y_val):
    t0 = time.time()
    model.fit(X_train, y_train)
    y_pred = model.predict(X_val)
    elapsed = time.time() - t0

    rmse = np.sqrt(mean_squared_error(y_val, y_pred))
    r2 = r2_score(y_val, y_pred)

    return {'Model': name, 'Line': line, 'Time(s)': elapsed, 'RMSE': rmse, 'R2': r2}

results = []
final_results = []

for line in df['Line'].unique():
    print(f"\n📘 [Line {line}] 모델 학습 중...")

    df_line = df[df['Line'] == line].copy()
    test_line = test[test['Line'] == line].copy()

    # 범주형 지정
    for col in ['STN', 'address']:
        df_line[col] = df_line[col].astype('category')
        test_line[col] = test_line[col].astype('category')

    df_line = df_line.sort_values('TM')

    # feature, target
    X = df_line[feature_cols]
    y = df_line[target_col].astype(int)
    X_test = test_line[feature_cols]

    # 인코딩
    X_enc = pd.get_dummies(X, columns=cat_cols, drop_first=False)
    X_test_enc = pd.get_dummies(X_test, columns=cat_cols, drop_first=False)

    # 컬럼 정렬 및 누락된 컬럼 채움
    X_enc = X_enc.loc[:, ~X_enc.columns.duplicated()]
    X_test_enc = X_test_enc.loc[:, ~X_test_enc.columns.duplicated()]
    X_test_enc = X_test_enc.reindex(columns=X_enc.columns, fill_value=0)

    # 정규화 후 float32로 다운캐스트
    mm = MinMaxScaler()
    X_scaled = mm.fit_transform(X_enc).astype(np.float32)
    X_test_scaled = mm.transform(X_test_enc).astype(np.float32)

    # 시간 순 분할
    split_idx = int(len(X_scaled) * 0.8)
    X_train = X_scaled[:split_idx]
    X_val = X_scaled[split_idx:]
    y_train = y.values[:split_idx]
    y_val = y.values[split_idx:]

    # 모델 정의 및 학습
    et = ExtraTreesRegressor(
        n_estimators=1500,
        max_depth=12,
        max_features=0.9,
        min_samples_split=2,
        min_samples_leaf=1,
        n_jobs=-1,
        random_state=42
    )
    res = evaluate_model('ET', et, line, X_train, y_train, X_val, y_val)
    results.append(res)
    print('✅ ExtraTrees 결과:', res)

    # 예측 및 저장
    y_pred = np.round(et.predict(X_test_scaled)).astype(int)
    y_pred = np.where(y_pred < 0, 0, y_pred)
    temp = test_line[['hour', 'Line', 'station_number']].copy()
    temp['예측혼잡도'] = y_pred
    final_results.append(temp)

    # 모델 저장 (압축)
    os.makedirs('./models', exist_ok=True)
    joblib.dump(et, f"./models/extratrees_line{line}.pkl", compress=3)

    # 메모리 정리
    del df_line, test_line, X, y, X_test
    del X_enc, X_test_enc, X_scaled, X_test_scaled
    del X_train, X_val, y_train, y_val, et, y_pred, temp
    gc.collect()

# 결과 저장
final_df = pd.concat(final_results)
output_df = final_df[['예측혼잡도']].rename(columns={'예측혼잡도': 'Congestion'})
os.makedirs('./test', exist_ok=True)
output_df.to_csv('./test/250206-et.csv', index=False, encoding='utf-8')

# 성능 요약 출력
results_df = pd.DataFrame(results)
print("\n📊 전체 성능 요약:")
print(results_df)
# Out:
# 📘 [Line 1] 모델 학습 중...
# ✅ ExtraTrees 결과: {'Model': 'ET', 'Line': 1, 'Time(s)': 7440.4131190776825, 'RMSE': 9.909858336973329, 'R2': 0.7665104761477816}
#
# 📘 [Line 2] 모델 학습 중...
# ✅ ExtraTrees 결과: {'Model': 'ET', 'Line': 2, 'Time(s)': 4069.8190853595734, 'RMSE': 9.054434823633885, 'R2': 0.8210492448064146}
#
# 📘 [Line 3] 모델 학습 중...
# KeyboardInterrupt

# %%
gap = pd.read_csv('./test/250206-et.csv') # 내 데터터
gap.shape

import os
제출 = pd.read_csv('./test/minjeong.csv') # 민정언니 데이터

import numpy as np

# 마스크 생성
from sklearn.metrics import root_mean_squared_error
rmse = mean_squared_error(
    제출['Congestion'],
    gap['Congestion'],
    squared=False      # squared=False 하면 RMSE 를 직접 계산해 줌
)

print(f"RMSE: {rmse:.4f}")

# %% [markdown]
# 검증결과 7.714

# %% [markdown]
# # XGB

# %%
import os
import time
import gc
import numpy as np
import pandas as pd
import joblib
import random
from tqdm import tqdm
from itertools import product
from sklearn.preprocessing import MinMaxScaler
from sklearn.metrics import mean_squared_error, r2_score
from xgboost import XGBRegressor

def evaluate_model(name, model, line, X_train, y_train, X_val, y_val):
    t0 = time.time()
    model.fit(X_train, y_train, eval_set=[(X_val, y_val)], verbose=False)
    y_pred = model.predict(X_val)
    elapsed = time.time() - t0

    rmse = np.sqrt(mean_squared_error(y_val, y_pred))
    r2 = r2_score(y_val, y_pred)

    return {'Model': name, 'Line': line, 'Time(s)': elapsed, 'RMSE': rmse, 'R2': r2}

# 랜덤서치용 하이퍼파라미터 그리드
param_grid = {
    'n_estimators': [1000, 1500, 2000],
    'learning_rate': [0.01, 0.05, 0.1],
    'max_depth': [8, 10, 12],
    'subsample': [0.8, 0.9],
    'colsample_bytree': [0.8, 0.9],
    'reg_alpha': [0, 0.3],
    'reg_lambda': [0.5, 0.8],
    'min_child_weight': [1, 3],
    'gamma': [0, 0.5],
}

# 랜덤 조합 15개 샘플링
param_list = list(product(*param_grid.values()))
random.seed(42)
sampled_params = random.sample(param_list, 30)
# sampled_params=param_list

results = []
final_results = []

for line in df['Line'].unique():
    print(f"\n📘 [Line {line}] 모델 학습 중...")

    df_line = df[df['Line'] == line].copy()
    test_line = test[test['Line'] == line].copy()

    for col in ['STN', 'address']:
        df_line[col] = df_line[col].astype('category')
        test_line[col] = test_line[col].astype('category')

    df_line = df_line.sort_values('TM')

    X = df_line[feature_cols]
    y = df_line[target_col].astype(int)
    X_test = test_line[feature_cols]

    X_enc = pd.get_dummies(X, columns=cat_cols, drop_first=False)
    X_test_enc = pd.get_dummies(X_test, columns=cat_cols, drop_first=False)
    X_enc.columns.duplicated()]
    X_test_enc = X_test_enc.loc[:, ~X_test_enc.columns.duplicated()]
    X_test_enc = X_test_enc.reindex(columns=X_enc.columns, fill_value=0)

    mm = MinMaxScaler()
    X_scaled = mm.fit_transform(X_enc).astype(np.float32)
    X_test_scaled = mm.transform(X_test_enc).astype(np.float32)

    split_idx = int(len(X_scaled) * 0.8)
    X_train = X_scaled[:split_idx]
    X_val = X_scaled[split_idx:]
    y_train = y.values[:split_idx]
    y_val = y.values[split_idx:]

    # ✅ 수동 랜덤서치 (교차검증 없이 val set으로 평가)
    best_model = None
    best_rmse = float('inf')

    for params in sampled_params:
        model = XGBRegressor(
            n_estimators=params[0],
            learning_rate=params[1],
            max_depth=params[2],
            subsample=params[3],
            colsample_bytree=params[4],
            reg_alpha=params[5],
            reg_lambda=params[6],
            min_child_weight=params[7],
            gamma=params[8],
            tree_method='hist',
            eval_metric='rmse',
            early_stopping_rounds=30,
            random_state=42,
            verbosity=0
        )

        model.fit(X_train, y_train, eval_set=[(X_val, y_val)], verbose=100)
        y_val_pred = model.predict(X_val)
        rmse = np.sqrt(mean_squared_error(y_val, y_val_pred))

        if rmse < best_rmse:
            best_rmse = rmse
            best_model = model

    # 평가
    res = evaluate_model('XGB', best_model, line, X_train, y_train, X_val, y_val)
    results.append(res)
    print('✅ XGB 결과:', res)
    print('🧪 최적 파라미터:', best_model.get_params())

    # 예측
    y_pred = np.round(best_model.predict(X_test_scaled)).astype(int)
    y_pred = np.where(y_pred < 0, 0, y_pred)
    temp = test_line[['hour', 'Line', 'station_number']].copy()
    temp['예측혼잡도'] = y_pred
    final_results.append(temp)

    os.makedirs('./models', exist_ok=True)
    joblib.dump(best_model, f"./models/xgb_line{line}.pkl", compress=3)

    del df_line, test_line, X, y, X_test
    del X_enc, X_test_enc, X_scaled, X_test_scaled
    del X_train, X_val, y_train, y_val, best_model, y_pred, temp
    gc.collect()

# 결과 저장
final_df = pd.concat(final_results)
output_df = final_df[['예측혼잡도']].rename(columns={'예측혼잡도': 'Congestion'})
os.makedirs('./test', exist_ok=True)
output_df.to_csv('./test/250206-xgb.csv', index=False, encoding='utf-8')

results_df = pd.DataFrame(results)
print("\n📊 전체 성능 요약:")
print(results_df)
# Out:
# 📘 [Line 1] 모델 학습 중...
# [0]	validation_0-rmse:20.67950
# [100]	validation_0-rmse:11.89829
# [200]	validation_0-rmse:7.97158
# [300]	validation_0-rmse:6.07793
# [400]	validation_0-rmse:5.31176
# [500]	validation_0-rmse:5.04130
# [600]	validation_0-rmse:4.89391
# [700]	validation_0-rmse:4.76490
# [800]	validation_0-rmse:4.65450
# [900]	validation_0-rmse:4.55036
# [1000]	validation_0-rmse:4.47896
# [1100]	validation_0-rmse:4.41607
# [1200]	validation_0-rmse:4.36560
# [1300]	validation_0-rmse:4.32653
# [1400]	validation_0-rmse:4.29663
# [1500]	validation_0-rmse:4.27170
# [1600]	validation_0-rmse:4.25128
# [1700]	validation_0-rmse:4.23570
# [1800]	validation_0-rmse:4.22040
# [1900]	validation_0-rmse:4.20593
# [1999]	validation_0-rmse:4.19329
# [0]	validation_0-rmse:20.36684
# [100]	validation_0-rmse:7.83633
# [200]	validation_0-rmse:6.56234
# [300]	validation_0-rmse:5.85892
# [400]	validation_0-rmse:5.45772
# [500]	validation_0-rmse:5.19289
# [600]	validation_0-rmse:4.99103
# [700]	validation_0-rmse:4.83981
# [800]	validation_0-rmse:4.69203
# [900]	validation_0-rmse:4.54888
# [999]	validation_0-rmse:4.47516
# [0]	validation_0-rmse:20.73126
# [100]	validation_0-rmse:13.79582
# [200]	validation_0-rmse:10.48928
# [300]	validation_0-rmse:9.19759
# [400]	validation_0-rmse:8.46991
# [500]	validation_0-rmse:7.99846
# [600]	validation_0-rmse:7.50495
# [700]	validation_0-rmse:7.11863
# [800]	validation_0-rmse:6.87245
# [900]	validation_0-rmse:6.68436
# [999]	validation_0-rmse:6.51635
# [0]	validation_0-rmse:20.27514
# [100]	validation_0-rmse:5.05032
# [200]	validation_0-rmse:4.43756
# [300]	validation_0-rmse:4.18801
# [400]	validation_0-rmse:4.12169
# [500]	validation_0-rmse:4.08802
# [600]	validation_0-rmse:4.06709
# [700]	validation_0-rmse:4.05029
# [800]	validation_0-rmse:4.04292
# [830]	validation_0-rmse:4.04401
# [0]	validation_0-rmse:19.30480
# [100]	validation_0-rmse:4.53387
# [200]	validation_0-rmse:4.26908
# [300]	validation_0-rmse:4.22981
# [400]	validation_0-rmse:4.21744
# [423]	validation_0-rmse:4.21884
# [0]	validation_0-rmse:19.54157
# [100]	validation_0-rmse:4.95650
# [200]	validation_0-rmse:4.32515
# [300]	validation_0-rmse:4.13369
# [400]	validation_0-rmse:4.07172
# [469]	validation_0-rmse:4.06644
# [0]	validation_0-rmse:19.84719
# [100]	validation_0-rmse:5.16625
# [200]	validation_0-rmse:4.44705
# [300]	validation_0-rmse:4.23349
# [400]	validation_0-rmse:4.16039
# [500]	validation_0-rmse:4.11789
# [600]	validation_0-rmse:4.09054
# [700]	validation_0-rmse:4.09083
# [705]	validation_0-rmse:4.09074
# [0]	validation_0-rmse:20.18168
# [100]	validation_0-rmse:6.03019
# [200]	validation_0-rmse:5.09263
# [300]	validation_0-rmse:4.65481
# [400]	validation_0-rmse:4.45621
# [500]	validation_0-rmse:4.31670
# [600]	validation_0-rmse:4.22150
# [700]	validation_0-rmse:4.17589
# [800]	validation_0-rmse:4.13851
# [900]	validation_0-rmse:4.10651
# [999]	validation_0-rmse:4.09198
# [0]	validation_0-rmse:20.28611
# [100]	validation_0-rmse:5.13361
# [200]	validation_0-rmse:4.59990
# [300]	validation_0-rmse:4.37270
# [400]	validation_0-rmse:4.29021
# [500]	validation_0-rmse:4.24914
# [600]	validation_0-rmse:4.23071
# [700]	validation_0-rmse:4.21941
# [725]	validation_0-rmse:4.21906
# [0]	validation_0-rmse:20.33080
# [100]	validation_0-rmse:7.86471
# [200]	validation_0-rmse:6.55612
# [300]	validation_0-rmse:5.83467
# [400]	validation_0-rmse:5.43212
# [500]	validation_0-rmse:5.11631
# [600]	validation_0-rmse:4.92854
# [700]	validation_0-rmse:4.78630
# [800]	validation_0-rmse:4.68269
# [900]	validation_0-rmse:4.57093
# [999]	validation_0-rmse:4.49596
# [0]	validation_0-rmse:20.36677
# [100]	validation_0-rmse:7.86660
# [200]	validation_0-rmse:6.53758
# [300]	validation_0-rmse:5.80140
# [400]	validation_0-rmse:5.37265
# [500]	validation_0-rmse:5.10197
# [600]	validation_0-rmse:4.85853
# [700]	validation_0-rmse:4.74641
# [800]	validation_0-rmse:4.61520
# [900]	validation_0-rmse:4.54391
# [1000]	validation_0-rmse:4.47306
# [1100]	validation_0-rmse:4.37387
# [1200]	validation_0-rmse:4.32481
# [1300]	validation_0-rmse:4.29456
# [1400]	validation_0-rmse:4.22054
# [1500]	validation_0-rmse:4.19290
# [1600]	validation_0-rmse:4.17232
# [1700]	validation_0-rmse:4.16677
# [1707]	validation_0-rmse:4.16477
# [0]	validation_0-rmse:20.28617
# [100]	validation_0-rmse:5.17231
# [200]	validation_0-rmse:4.59955
# [300]	validation_0-rmse:4.37313
# [400]	validation_0-rmse:4.30317
# [500]	validation_0-rmse:4.25657
# [600]	validation_0-rmse:4.22427
# [700]	validation_0-rmse:4.21018
# [784]	validation_0-rmse:4.20843
# [0]	validation_0-rmse:19.32048
# [100]	validation_0-rmse:4.60524
# [200]	validation_0-rmse:4.30316
# [300]	validation_0-rmse:4.26521
# [338]	validation_0-rmse:4.26377
# [0]	validation_0-rmse:20.67795
# [100]	validation_0-rmse:11.85051
# [200]	validation_0-rmse:7.86465
# [300]	validation_0-rmse:5.97602
# [400]	validation_0-rmse:5.20746
# [500]	validation_0-rmse:4.93621
# [600]	validation_0-rmse:4.78085
# [700]	validation_0-rmse:4.65043
# [800]	validation_0-rmse:4.53617
# [900]	validation_0-rmse:4.44248
# [999]	validation_0-rmse:4.37274
# [0]	validation_0-rmse:20.73126
# [100]	validation_0-rmse:13.79600
# [200]	validation_0-rmse:10.48891
# [300]	validation_0-rmse:9.20313
# [400]	validation_0-rmse:8.48046
# [500]	validation_0-rmse:8.09800
# [600]	validation_0-rmse:7.55821
# [700]	validation_0-rmse:7.18295
# [800]	validation_0-rmse:6.94367
# [900]	validation_0-rmse:6.72838
# [1000]	validation_0-rmse:6.57383
# [1100]	validation_0-rmse:6.42763
# [1200]	validation_0-rmse:6.28632
# [1300]	validation_0-rmse:6.16129
# [1400]	validation_0-rmse:6.05376
# [1500]	validation_0-rmse:5.95105
# [1600]	validation_0-rmse:5.86304
# [1700]	validation_0-rmse:5.77877
# [1800]	validation_0-rmse:5.68016
# [1900]	validation_0-rmse:5.60426
# [1999]	validation_0-rmse:5.53884
# [0]	validation_0-rmse:20.33223
# [100]	validation_0-rmse:5.91549
# [200]	validation_0-rmse:5.08563
# [300]	validation_0-rmse:4.65671
# [400]	validation_0-rmse:4.43616
# [500]	validation_0-rmse:4.28578
# [600]	validation_0-rmse:4.19928
# [700]	validation_0-rmse:4.15087
# [800]	validation_0-rmse:4.10995
# [900]	validation_0-rmse:4.08525
# [1000]	validation_0-rmse:4.07294
# [1015]	validation_0-rmse:4.07262
# [0]	validation_0-rmse:20.73167
# [100]	validation_0-rmse:12.73538
# [200]	validation_0-rmse:8.96572
# [300]	validation_0-rmse:7.23289
# [400]	validation_0-rmse:6.48489
# [500]	validation_0-rmse:6.15773
# [600]	validation_0-rmse:5.92546
# [700]	validation_0-rmse:5.71444
# [800]	validation_0-rmse:5.50496
# [900]	validation_0-rmse:5.34191
# [999]	validation_0-rmse:5.21063
# [0]	validation_0-rmse:20.73127
# [100]	validation_0-rmse:13.78505
# [200]	validation_0-rmse:10.50682
# [300]	validation_0-rmse:9.20294
# [400]	validation_0-rmse:8.47579
# [500]	validation_0-rmse:7.99282
# [600]	validation_0-rmse:7.50330
# [700]	validation_0-rmse:7.13990
# [800]	validation_0-rmse:6.88871
# [900]	validation_0-rmse:6.69209
# [999]	validation_0-rmse:6.52775
# [0]	validation_0-rmse:20.67808
# [100]	validation_0-rmse:11.86696
# [200]	validation_0-rmse:7.87154
# [300]	validation_0-rmse:5.97931
# [400]	validation_0-rmse:5.16240
# [500]	validation_0-rmse:4.88965
# [600]	validation_0-rmse:4.75106
# [700]	validation_0-rmse:4.63660
# [800]	validation_0-rmse:4.53125
# [900]	validation_0-rmse:4.44203
# [999]	validation_0-rmse:4.36579
# [0]	validation_0-rmse:19.84011
# [100]	validation_0-rmse:6.53340
# [200]	validation_0-rmse:5.52029
# [300]	validation_0-rmse:4.99457
# [400]	validation_0-rmse:4.65988
# [500]	validation_0-rmse:4.46578
# [600]	validation_0-rmse:4.37012
# [700]	validation_0-rmse:4.28777
# [800]	validation_0-rmse:4.24579
# [900]	validation_0-rmse:4.20118
# [999]	validation_0-rmse:4.18457
# [0]	validation_0-rmse:19.54098
# [100]	validation_0-rmse:5.07855
# [200]	validation_0-rmse:4.46909
# [300]	validation_0-rmse:4.27514
# [400]	validation_0-rmse:4.19945
# [500]	validation_0-rmse:4.16532
# [600]	validation_0-rmse:4.14618
# [700]	validation_0-rmse:4.13627
# [716]	validation_0-rmse:4.14079
# [0]	validation_0-rmse:19.84712
# [100]	validation_0-rmse:5.21849
# [200]	validation_0-rmse:4.46171
# [300]	validation_0-rmse:4.22035
# [400]	validation_0-rmse:4.13940
# [500]	validation_0-rmse:4.09550
# [600]	validation_0-rmse:4.08121
# [700]	validation_0-rmse:4.07068
# [725]	validation_0-rmse:4.06867
# [0]	validation_0-rmse:20.70108
# [100]	validation_0-rmse:12.73403
# [200]	validation_0-rmse:8.80607
# [300]	validation_0-rmse:7.08175
# [400]	validation_0-rmse:6.44722
# [500]	validation_0-rmse:6.10873
# [600]	validation_0-rmse:5.86951
# [700]	validation_0-rmse:5.65719
# [800]	validation_0-rmse:5.45972
# [900]	validation_0-rmse:5.29511
# [1000]	validation_0-rmse:5.13157
# [1100]	validation_0-rmse:5.01273
# [1200]	validation_0-rmse:4.90608
# [1300]	validation_0-rmse:4.81331
# [1400]	validation_0-rmse:4.74180
# [1500]	validation_0-rmse:4.67154
# [1600]	validation_0-rmse:4.61839
# [1700]	validation_0-rmse:4.57281
# [1800]	validation_0-rmse:4.53460
# [1900]	validation_0-rmse:4.49772
# [1999]	validation_0-rmse:4.46617
# [0]	validation_0-rmse:20.73127
# [100]	validation_0-rmse:13.78505
# [200]	validation_0-rmse:10.48801
# [300]	validation_0-rmse:9.21347
# [400]	validation_0-rmse:8.49036
# [500]	validation_0-rmse:8.08592
# [600]	validation_0-rmse:7.54634
# [700]	validation_0-rmse:7.19557
# [800]	validation_0-rmse:6.93072
# [900]	validation_0-rmse:6.73582
# [999]	validation_0-rmse:6.57277
# [0]	validation_0-rmse:19.31398
# [100]	validation_0-rmse:4.62250
# [200]	validation_0-rmse:4.35672
# [300]	validation_0-rmse:4.30161
# [400]	validation_0-rmse:4.28336
# [409]	validation_0-rmse:4.28201
# [0]	validation_0-rmse:19.83961
# [100]	validation_0-rmse:6.71902
# [200]	validation_0-rmse:5.39903
# [300]	validation_0-rmse:4.86693
# [400]	validation_0-rmse:4.61530
# [463]	validation_0-rmse:4.55155
# [0]	validation_0-rmse:20.18159
# [100]	validation_0-rmse:6.27812
# [200]	validation_0-rmse:5.25965
# [300]	validation_0-rmse:4.75109
# [400]	validation_0-rmse:4.52945
# [500]	validation_0-rmse:4.41104
# [600]	validation_0-rmse:4.30012
# [700]	validation_0-rmse:4.24907
# [800]	validation_0-rmse:4.20719
# [900]	validation_0-rmse:4.18406
# [1000]	validation_0-rmse:4.16956
# [1100]	validation_0-rmse:4.15132
# [1155]	validation_0-rmse:4.15021
# [0]	validation_0-rmse:20.67795
# [100]	validation_0-rmse:11.85051
# [200]	validation_0-rmse:7.86465
# [300]	validation_0-rmse:5.97602
# [400]	validation_0-rmse:5.20746
# [500]	validation_0-rmse:4.93621
# [600]	validation_0-rmse:4.78085
# [700]	validation_0-rmse:4.65043
# [800]	validation_0-rmse:4.53617
# [900]	validation_0-rmse:4.44248
# [1000]	validation_0-rmse:4.37077
# [1100]	validation_0-rmse:4.31412
# [1200]	validation_0-rmse:4.25966
# [1300]	validation_0-rmse:4.21883
# [1400]	validation_0-rmse:4.18660
# [1500]	validation_0-rmse:4.15999
# [1600]	validation_0-rmse:4.14233
# [1700]	validation_0-rmse:4.12338
# [1800]	validation_0-rmse:4.10735
# [1900]	validation_0-rmse:4.09415
# [1999]	validation_0-rmse:4.08104
# [0]	validation_0-rmse:20.18168
# [100]	validation_0-rmse:6.03145
# [200]	validation_0-rmse:5.14128
# [300]	validation_0-rmse:4.69146
# [400]	validation_0-rmse:4.48529
# [500]	validation_0-rmse:4.36766
# [600]	validation_0-rmse:4.29067
# [700]	validation_0-rmse:4.22965
# [800]	validation_0-rmse:4.19688
# [900]	validation_0-rmse:4.16300
# [1000]	validation_0-rmse:4.15261
# [1006]	validation_0-rmse:4.15205
# [0]	validation_0-rmse:20.18002
# [100]	validation_0-rmse:6.09885
# [200]	validation_0-rmse:5.17034
# [300]	validation_0-rmse:4.73550
# [400]	validation_0-rmse:4.51800
# [500]	validation_0-rmse:4.38272
# [600]	validation_0-rmse:4.27527
# [700]	validation_0-rmse:4.21993
# [800]	validation_0-rmse:4.18110
# [900]	validation_0-rmse:4.14705
# [1000]	validation_0-rmse:4.12761
# [1100]	validation_0-rmse:4.11849
# [1200]	validation_0-rmse:4.10260
# [1300]	validation_0-rmse:4.09555
# [1400]	validation_0-rmse:4.08469
# [1443]	validation_0-rmse:4.08458
# ✅ XGB 결과: {'Model': 'XGB', 'Line': 1, 'Time(s)': 712.7675206661224, 'RMSE': 4.042833518966586, 'R2': 0.9611398723725793}
#
# 📘 [Line 2] 모델 학습 중...
# [0]	validation_0-rmse:22.00934
# [100]	validation_0-rmse:12.58468
# [200]	validation_0-rmse:10.11430
# [300]	validation_0-rmse:9.50044
# [400]	validation_0-rmse:9.12549
# [500]	validation_0-rmse:8.77892
# [600]	validation_0-rmse:8.58260
# [700]	validation_0-rmse:8.43711
# [800]	validation_0-rmse:8.31659
# [900]	validation_0-rmse:8.22392
# [1000]	validation_0-rmse:8.14907
# [1100]	validation_0-rmse:8.09453
# [1200]	validation_0-rmse:8.04762
# [1300]	validation_0-rmse:8.02078
# [1400]	validation_0-rmse:8.00018
# [1500]	validation_0-rmse:7.98323
# [1600]	validation_0-rmse:7.96993
# [1700]	validation_0-rmse:7.95920
# [1800]	validation_0-rmse:7.95067
# [1900]	validation_0-rmse:7.94109
# [1999]	validation_0-rmse:7.93325
# [0]	validation_0-rmse:21.60549
# [100]	validation_0-rmse:10.38710
# [200]	validation_0-rmse:8.99734
# [300]	validation_0-rmse:8.39355
# [368]	validation_0-rmse:8.27672
# [0]	validation_0-rmse:22.04412
# [100]	validation_0-rmse:14.52363
# [200]	validation_0-rmse:12.04772
# [300]	validation_0-rmse:11.12669
# [400]	validation_0-rmse:10.32832
# [500]	validation_0-rmse:9.82946
# [600]	validation_0-rmse:9.41625
# [700]	validation_0-rmse:9.09491
# [800]	validation_0-rmse:8.84079
# [900]	validation_0-rmse:8.64341
# [999]	validation_0-rmse:8.48075
# [0]	validation_0-rmse:21.42276
# [100]	validation_0-rmse:9.27319
# [200]	validation_0-rmse:8.67868
# [300]	validation_0-rmse:8.50251
# [400]	validation_0-rmse:8.44496
# [500]	validation_0-rmse:8.40827
# [600]	validation_0-rmse:8.39077
# [700]	validation_0-rmse:8.38064
# [717]	validation_0-rmse:8.38187
# [0]	validation_0-rmse:20.70113
# [100]	validation_0-rmse:8.95115
# [200]	validation_0-rmse:8.78351
# [300]	validation_0-rmse:8.76021
# [332]	validation_0-rmse:8.76307
# [0]	validation_0-rmse:20.93694
# [100]	validation_0-rmse:9.27971
# [200]	validation_0-rmse:8.97872
# [0]	validation_0-rmse:20.93742
# [62]	validation_0-rmse:10.20961
# [0]	validation_0-rmse:21.53987
# [100]	validation_0-rmse:9.78618
# [200]	validation_0-rmse:8.93991
# [300]	validation_0-rmse:8.65950
# [400]	validation_0-rmse:8.56575
# [453]	validation_0-rmse:8.56146
# [0]	validation_0-rmse:21.42265
# [100]	validation_0-rmse:9.41585
# [200]	validation_0-rmse:8.87329
# [300]	validation_0-rmse:8.72570
# [400]	validation_0-rmse:8.66786
# [500]	validation_0-rmse:8.64950
# [540]	validation_0-rmse:8.65197
# [0]	validation_0-rmse:21.60529
# [100]	validation_0-rmse:9.73049
# [200]	validation_0-rmse:8.47384
# [300]	validation_0-rmse:7.95901
# [400]	validation_0-rmse:7.67612
# [500]	validation_0-rmse:7.49658
# [581]	validation_0-rmse:7.42062
# [0]	validation_0-rmse:21.60546
# [100]	validation_0-rmse:9.97572
# [200]	validation_0-rmse:8.43391
# [300]	validation_0-rmse:7.91969
# [400]	validation_0-rmse:7.64210
# [500]	validation_0-rmse:7.46108
# [518]	validation_0-rmse:7.46746
# [0]	validation_0-rmse:21.42266
# [100]	validation_0-rmse:9.53657
# [200]	validation_0-rmse:8.92923
# [300]	validation_0-rmse:8.76303
# [400]	validation_0-rmse:8.70306
# [500]	validation_0-rmse:8.67941
# [600]	validation_0-rmse:8.66500
# [700]	validation_0-rmse:8.65328
# [800]	validation_0-rmse:8.63953
# [900]	validation_0-rmse:8.63070
# [932]	validation_0-rmse:8.63348
# [0]	validation_0-rmse:20.71718
# [100]	validation_0-rmse:8.62117
# [200]	validation_0-rmse:8.41819
# [300]	validation_0-rmse:8.39116
# [375]	validation_0-rmse:8.39405
# [0]	validation_0-rmse:22.00776
# [100]	validation_0-rmse:12.52550
# [200]	validation_0-rmse:10.18045
# [300]	validation_0-rmse:9.50665
# [400]	validation_0-rmse:9.20360
# [500]	validation_0-rmse:8.82338
# [600]	validation_0-rmse:8.61929
# [700]	validation_0-rmse:8.47266
# [800]	validation_0-rmse:8.36820
# [900]	validation_0-rmse:8.27585
# [999]	validation_0-rmse:8.20830
# [0]	validation_0-rmse:22.04411
# [100]	validation_0-rmse:14.52475
# [200]	validation_0-rmse:12.13984
# [300]	validation_0-rmse:11.21072
# [400]	validation_0-rmse:10.37389
# [500]	validation_0-rmse:9.98246
# [600]	validation_0-rmse:9.59143
# [700]	validation_0-rmse:9.28681
# [800]	validation_0-rmse:9.05145
# [900]	validation_0-rmse:8.85376
# [1000]	validation_0-rmse:8.67835
# [1100]	validation_0-rmse:8.53679
# [1200]	validation_0-rmse:8.40536
# [1300]	validation_0-rmse:8.25996
# [1400]	validation_0-rmse:8.14893
# [1500]	validation_0-rmse:8.04852
# [1600]	validation_0-rmse:7.96091
# [1700]	validation_0-rmse:7.89155
# [1800]	validation_0-rmse:7.83252
# [1900]	validation_0-rmse:7.77965
# [1999]	validation_0-rmse:7.73730
# [0]	validation_0-rmse:21.53999
# [100]	validation_0-rmse:10.05265
# [200]	validation_0-rmse:9.15132
# [300]	validation_0-rmse:8.86900
# [400]	validation_0-rmse:8.79616
# [500]	validation_0-rmse:8.74614
# [524]	validation_0-rmse:8.75313
# [0]	validation_0-rmse:22.03107
# [100]	validation_0-rmse:13.48943
# [200]	validation_0-rmse:11.07171
# [300]	validation_0-rmse:10.13255
# [400]	validation_0-rmse:9.65674
# [500]	validation_0-rmse:9.29507
# [600]	validation_0-rmse:9.01814
# [700]	validation_0-rmse:8.77592
# [800]	validation_0-rmse:8.57515
# [900]	validation_0-rmse:8.41913
# [999]	validation_0-rmse:8.29799
# [0]	validation_0-rmse:22.04412
# [100]	validation_0-rmse:14.53495
# [200]	validation_0-rmse:12.17529
# [300]	validation_0-rmse:11.27034
# [400]	validation_0-rmse:10.38615
# [500]	validation_0-rmse:9.96364
# [600]	validation_0-rmse:9.53117
# [700]	validation_0-rmse:9.20301
# [800]	validation_0-rmse:8.95024
# [900]	validation_0-rmse:8.74499
# [999]	validation_0-rmse:8.59128
# [0]	validation_0-rmse:22.00775
# [100]	validation_0-rmse:12.52544
# [200]	validation_0-rmse:10.14710
# [300]	validation_0-rmse:9.46095
# [400]	validation_0-rmse:9.07710
# [500]	validation_0-rmse:8.67733
# [600]	validation_0-rmse:8.46554
# [700]	validation_0-rmse:8.31604
# [800]	validation_0-rmse:8.20464
# [900]	validation_0-rmse:8.11360
# [999]	validation_0-rmse:8.04099
# [0]	validation_0-rmse:21.06804
# [100]	validation_0-rmse:8.98259
# [200]	validation_0-rmse:8.38473
# [297]	validation_0-rmse:8.11504
# [0]	validation_0-rmse:20.93670
# [100]	validation_0-rmse:8.23596
# [200]	validation_0-rmse:7.84601
# [280]	validation_0-rmse:7.80833
# [0]	validation_0-rmse:20.93800
# [100]	validation_0-rmse:9.11210
# [200]	validation_0-rmse:8.58676
# [300]	validation_0-rmse:8.53702
# [400]	validation_0-rmse:8.51915
# [500]	validation_0-rmse:8.51968
# [506]	validation_0-rmse:8.51927
# [0]	validation_0-rmse:22.03104
# [100]	validation_0-rmse:13.25033
# [200]	validation_0-rmse:11.08877
# [300]	validation_0-rmse:10.25684
# [400]	validation_0-rmse:9.64664
# [500]	validation_0-rmse:9.21467
# [600]	validation_0-rmse:8.95256
# [700]	validation_0-rmse:8.74824
# [800]	validation_0-rmse:8.59511
# [900]	validation_0-rmse:8.44468
# [1000]	validation_0-rmse:8.33223
# [1100]	validation_0-rmse:8.22846
# [1200]	validation_0-rmse:8.15472
# [1300]	validation_0-rmse:8.08753
# [1400]	validation_0-rmse:8.03479
# [1500]	validation_0-rmse:8.00105
# [1600]	validation_0-rmse:7.96844
# [1700]	validation_0-rmse:7.94141
# [1800]	validation_0-rmse:7.91577
# [1900]	validation_0-rmse:7.89983
# [1999]	validation_0-rmse:7.87874
# [0]	validation_0-rmse:22.04412
# [100]	validation_0-rmse:14.53408
# [200]	validation_0-rmse:12.17510
# [300]	validation_0-rmse:11.22124
# [400]	validation_0-rmse:10.45369
# [500]	validation_0-rmse:9.98113
# [600]	validation_0-rmse:9.57047
# [700]	validation_0-rmse:9.25300
# [800]	validation_0-rmse:9.01654
# [900]	validation_0-rmse:8.80831
# [999]	validation_0-rmse:8.64451
# [0]	validation_0-rmse:20.70069
# [100]	validation_0-rmse:8.26455
# [200]	validation_0-rmse:8.12903
# [300]	validation_0-rmse:8.10493
# [354]	validation_0-rmse:8.10620
# [0]	validation_0-rmse:21.06765
# [100]	validation_0-rmse:8.69810
# [200]	validation_0-rmse:7.90616
# [300]	validation_0-rmse:7.63593
# [400]	validation_0-rmse:7.53843
# [500]	validation_0-rmse:7.47431
# [600]	validation_0-rmse:7.42007
# [654]	validation_0-rmse:7.42101
# [0]	validation_0-rmse:21.54029
# [100]	validation_0-rmse:9.81697
# [200]	validation_0-rmse:8.98539
# [300]	validation_0-rmse:8.68404
# [400]	validation_0-rmse:8.57851
# [423]	validation_0-rmse:8.57196
# [0]	validation_0-rmse:22.00776
# [100]	validation_0-rmse:12.52550
# [200]	validation_0-rmse:10.18045
# [300]	validation_0-rmse:9.50665
# [400]	validation_0-rmse:9.20360
# [500]	validation_0-rmse:8.82338
# [600]	validation_0-rmse:8.61929
# [700]	validation_0-rmse:8.47266
# [800]	validation_0-rmse:8.36820
# [900]	validation_0-rmse:8.27585
# [1000]	validation_0-rmse:8.20819
# [1100]	validation_0-rmse:8.15047
# [1200]	validation_0-rmse:8.10885
# [1300]	validation_0-rmse:8.07669
# [1400]	validation_0-rmse:8.05479
# [1500]	validation_0-rmse:8.03967
# [1600]	validation_0-rmse:8.02626
# [1700]	validation_0-rmse:8.01388
# [1800]	validation_0-rmse:8.00692
# [1900]	validation_0-rmse:7.99937
# [1999]	validation_0-rmse:7.99435
# [0]	validation_0-rmse:21.53987
# [100]	validation_0-rmse:9.47400
# [200]	validation_0-rmse:8.68102
# [300]	validation_0-rmse:8.38730
# [400]	validation_0-rmse:8.26421
# [500]	validation_0-rmse:8.22962
# [600]	validation_0-rmse:8.18585
# [685]	validation_0-rmse:8.17135
# [0]	validation_0-rmse:21.54033
# [100]	validation_0-rmse:9.73013
# [200]	validation_0-rmse:8.89375
# [300]	validation_0-rmse:8.62587
# [400]	validation_0-rmse:8.49381
# [500]	validation_0-rmse:8.43879
# [518]	validation_0-rmse:8.43656
# ✅ XGB 결과: {'Model': 'XGB', 'Line': 2, 'Time(s)': 306.1369607448578, 'RMSE': 7.401646870842782, 'R2': 0.8804175177175011}
#
# 📘 [Line 3] 모델 학습 중...
# [0]	validation_0-rmse:19.93601
# [100]	validation_0-rmse:10.12384
# [200]	validation_0-rmse:6.79674
# [300]	validation_0-rmse:5.40314
# [400]	validation_0-rmse:5.28883
# [500]	validation_0-rmse:5.04305
# [600]	validation_0-rmse:4.89595
# [700]	validation_0-rmse:4.78756
# [800]	validation_0-rmse:4.70764
# [900]	validation_0-rmse:4.65624
# [1000]	validation_0-rmse:4.62591
# [1100]	validation_0-rmse:4.59880
# [1200]	validation_0-rmse:4.58024
# [1300]	validation_0-rmse:4.56743
# [1400]	validation_0-rmse:4.55495
# [1500]	validation_0-rmse:4.54650
# [1600]	validation_0-rmse:4.54203
# [1659]	validation_0-rmse:4.54036
# [0]	validation_0-rmse:19.50710
# [100]	validation_0-rmse:6.75876
# [200]	validation_0-rmse:5.60659
# [300]	validation_0-rmse:5.34309
# [400]	validation_0-rmse:5.25624
# [500]	validation_0-rmse:5.17576
# [544]	validation_0-rmse:5.19914
# [0]	validation_0-rmse:19.96961
# [100]	validation_0-rmse:12.90797
# [200]	validation_0-rmse:8.73828
# [300]	validation_0-rmse:7.36691
# [400]	validation_0-rmse:6.87689
# [500]	validation_0-rmse:6.72191
# [600]	validation_0-rmse:6.58586
# [614]	validation_0-rmse:6.54097
# [0]	validation_0-rmse:19.34543
# [100]	validation_0-rmse:4.71453
# [200]	validation_0-rmse:4.28603
# [300]	validation_0-rmse:4.27049
# [364]	validation_0-rmse:4.26459
# [0]	validation_0-rmse:18.59906
# [100]	validation_0-rmse:4.87628
# [199]	validation_0-rmse:4.83462
# [0]	validation_0-rmse:18.77966
# [100]	validation_0-rmse:5.01341
# [200]	validation_0-rmse:4.81112
# [295]	validation_0-rmse:4.81416
# [0]	validation_0-rmse:18.79136
# [100]	validation_0-rmse:5.31352
# [200]	validation_0-rmse:5.19052
# [218]	validation_0-rmse:5.18101
# [0]	validation_0-rmse:19.43181
# [100]	validation_0-rmse:5.48408
# [200]	validation_0-rmse:4.78220
# [244]	validation_0-rmse:4.76305
# [0]	validation_0-rmse:19.34512
# [100]	validation_0-rmse:5.01117
# [200]	validation_0-rmse:4.61357
# [300]	validation_0-rmse:4.54657
# [400]	validation_0-rmse:4.52507
# [477]	validation_0-rmse:4.51787
# [0]	validation_0-rmse:19.50624
# [100]	validation_0-rmse:6.57036
# [200]	validation_0-rmse:5.58620
# [300]	validation_0-rmse:5.29965
# [400]	validation_0-rmse:5.11465
# [497]	validation_0-rmse:5.06230
# [0]	validation_0-rmse:19.50704
# [100]	validation_0-rmse:6.77674
# [200]	validation_0-rmse:5.94224
# [300]	validation_0-rmse:5.60722
# [400]	validation_0-rmse:5.43446
# [486]	validation_0-rmse:5.40157
# [0]	validation_0-rmse:19.34513
# [100]	validation_0-rmse:4.99862
# [200]	validation_0-rmse:4.61223
# [218]	validation_0-rmse:4.59756
# [0]	validation_0-rmse:18.59622
# [100]	validation_0-rmse:4.26655
# [144]	validation_0-rmse:4.46800
# [0]	validation_0-rmse:19.93628
# [100]	validation_0-rmse:10.13307
# [200]	validation_0-rmse:6.74956
# [300]	validation_0-rmse:5.34934
# [400]	validation_0-rmse:5.13953
# [500]	validation_0-rmse:4.93883
# [600]	validation_0-rmse:4.81758
# [700]	validation_0-rmse:4.70549
# [800]	validation_0-rmse:4.63839
# [900]	validation_0-rmse:4.59252
# [999]	validation_0-rmse:4.56706
# [0]	validation_0-rmse:19.96961
# [100]	validation_0-rmse:12.90798
# [200]	validation_0-rmse:8.75723
# [300]	validation_0-rmse:7.36782
# [400]	validation_0-rmse:6.84297
# [500]	validation_0-rmse:6.66576
# [600]	validation_0-rmse:6.43774
# [700]	validation_0-rmse:6.19617
# [800]	validation_0-rmse:5.95194
# [900]	validation_0-rmse:5.79819
# [1000]	validation_0-rmse:5.66983
# [1100]	validation_0-rmse:5.59728
# [1200]	validation_0-rmse:5.53495
# [1269]	validation_0-rmse:5.52064
# [0]	validation_0-rmse:19.43183
# [100]	validation_0-rmse:5.18782
# [200]	validation_0-rmse:4.51544
# [300]	validation_0-rmse:4.35275
# [400]	validation_0-rmse:4.28446
# [500]	validation_0-rmse:4.24890
# [600]	validation_0-rmse:4.21856
# [647]	validation_0-rmse:4.21707
# [0]	validation_0-rmse:19.95545
# [100]	validation_0-rmse:11.21457
# [200]	validation_0-rmse:7.55451
# [300]	validation_0-rmse:6.71109
# [400]	validation_0-rmse:6.20735
# [434]	validation_0-rmse:6.18997
# [0]	validation_0-rmse:19.96962
# [100]	validation_0-rmse:12.90505
# [200]	validation_0-rmse:8.74925
# [300]	validation_0-rmse:7.38499
# [400]	validation_0-rmse:6.86900
# [500]	validation_0-rmse:6.71211
# [600]	validation_0-rmse:6.43672
# [700]	validation_0-rmse:6.20693
# [800]	validation_0-rmse:6.00014
# [900]	validation_0-rmse:5.84023
# [999]	validation_0-rmse:5.71742
# [0]	validation_0-rmse:19.93634
# [100]	validation_0-rmse:10.12965
# [200]	validation_0-rmse:6.77266
# [300]	validation_0-rmse:5.38464
# [337]	validation_0-rmse:5.37358
# [0]	validation_0-rmse:18.93472
# [100]	validation_0-rmse:5.49760
# [200]	validation_0-rmse:5.17529
# [300]	validation_0-rmse:5.06326
# [400]	validation_0-rmse:4.98916
# [460]	validation_0-rmse:5.07842
# [0]	validation_0-rmse:18.78576
# [100]	validation_0-rmse:4.62948
# [200]	validation_0-rmse:4.41931
# [300]	validation_0-rmse:4.37002
# [321]	validation_0-rmse:4.37726
# [0]	validation_0-rmse:18.79128
# [100]	validation_0-rmse:4.97045
# [200]	validation_0-rmse:4.82499
# [244]	validation_0-rmse:4.86335
# [0]	validation_0-rmse:19.95490
# [100]	validation_0-rmse:11.28727
# [200]	validation_0-rmse:7.52258
# [300]	validation_0-rmse:6.77127
# [400]	validation_0-rmse:6.02702
# [500]	validation_0-rmse:5.69431
# [600]	validation_0-rmse:5.42160
# [700]	validation_0-rmse:5.22826
# [800]	validation_0-rmse:5.07705
# [900]	validation_0-rmse:4.96837
# [1000]	validation_0-rmse:4.88845
# [1100]	validation_0-rmse:4.83296
# [1200]	validation_0-rmse:4.79578
# [1300]	validation_0-rmse:4.77243
# [1400]	validation_0-rmse:4.75987
# [1425]	validation_0-rmse:4.77064
# [0]	validation_0-rmse:19.96962
# [100]	validation_0-rmse:12.90846
# [200]	validation_0-rmse:8.69548
# [300]	validation_0-rmse:7.42863
# [400]	validation_0-rmse:7.00141
# [479]	validation_0-rmse:6.89036
# [0]	validation_0-rmse:18.59892
# [100]	validation_0-rmse:4.71661
# [176]	validation_0-rmse:4.67732
# [0]	validation_0-rmse:18.93569
# [100]	validation_0-rmse:5.57666
# [200]	validation_0-rmse:5.17313
# [271]	validation_0-rmse:5.11080
# [0]	validation_0-rmse:19.42857
# [100]	validation_0-rmse:5.91475
# [200]	validation_0-rmse:5.13219
# [264]	validation_0-rmse:5.06401
# [0]	validation_0-rmse:19.93628
# [100]	validation_0-rmse:10.13307
# [200]	validation_0-rmse:6.74956
# [300]	validation_0-rmse:5.34934
# [400]	validation_0-rmse:5.13953
# [500]	validation_0-rmse:4.93883
# [600]	validation_0-rmse:4.81758
# [700]	validation_0-rmse:4.70549
# [800]	validation_0-rmse:4.63839
# [900]	validation_0-rmse:4.59252
# [1000]	validation_0-rmse:4.56664
# [1100]	validation_0-rmse:4.54467
# [1200]	validation_0-rmse:4.52532
# [1300]	validation_0-rmse:4.51107
# [1400]	validation_0-rmse:4.49938
# [1500]	validation_0-rmse:4.49057
# [1600]	validation_0-rmse:4.48581
# [1700]	validation_0-rmse:4.47853
# [1740]	validation_0-rmse:4.47865
# [0]	validation_0-rmse:19.43181
# [100]	validation_0-rmse:5.57051
# [200]	validation_0-rmse:4.82441
# [300]	validation_0-rmse:4.74913
# [340]	validation_0-rmse:4.75326
# [0]	validation_0-rmse:19.43168
# [100]	validation_0-rmse:5.85839
# [200]	validation_0-rmse:5.11867
# [300]	validation_0-rmse:4.98404
# [400]	validation_0-rmse:4.91138
# [500]	validation_0-rmse:4.87758
# [600]	validation_0-rmse:4.85558
# [660]	validation_0-rmse:4.85279
# ✅ XGB 결과: {'Model': 'XGB', 'Line': 3, 'Time(s)': 372.65375995635986, 'RMSE': 4.214565522170867, 'R2': 0.9548766978052899}
#
# 📘 [Line 4] 모델 학습 중...
# [0]	validation_0-rmse:21.74260
# [100]	validation_0-rmse:11.06884
# [200]	validation_0-rmse:7.30460
# [300]	validation_0-rmse:6.03340
# [400]	validation_0-rmse:5.38424
# [500]	validation_0-rmse:5.06141
# [600]	validation_0-rmse:4.89579
# [700]	validation_0-rmse:4.77966
# [800]	validation_0-rmse:4.69556
# [900]	validation_0-rmse:4.59542
# [1000]	validation_0-rmse:4.51963
# [1100]	validation_0-rmse:4.45974
# [1200]	validation_0-rmse:4.41351
# [1300]	validation_0-rmse:4.37513
# [1400]	validation_0-rmse:4.34508
# [1500]	validation_0-rmse:4.31769
# [1600]	validation_0-rmse:4.29247
# [1700]	validation_0-rmse:4.27652
# [1800]	validation_0-rmse:4.26241
# [1900]	validation_0-rmse:4.24926
# [1999]	validation_0-rmse:4.23927
# [0]	validation_0-rmse:21.42682
# [100]	validation_0-rmse:8.68206
# [200]	validation_0-rmse:7.15814
# [300]	validation_0-rmse:6.36336
# [400]	validation_0-rmse:5.84762
# [500]	validation_0-rmse:5.42969
# [600]	validation_0-rmse:5.18192
# [700]	validation_0-rmse:4.99967
# [800]	validation_0-rmse:4.88294
# [900]	validation_0-rmse:4.77282
# [999]	validation_0-rmse:4.70363
# [0]	validation_0-rmse:21.79244
# [100]	validation_0-rmse:14.50556
# [200]	validation_0-rmse:11.56611
# [300]	validation_0-rmse:10.16719
# [400]	validation_0-rmse:9.33393
# [500]	validation_0-rmse:8.75567
# [600]	validation_0-rmse:8.38374
# [700]	validation_0-rmse:8.07728
# [800]	validation_0-rmse:7.82375
# [900]	validation_0-rmse:7.59655
# [999]	validation_0-rmse:7.39618
# [0]	validation_0-rmse:21.16638
# [100]	validation_0-rmse:5.16628
# [200]	validation_0-rmse:4.47111
# [300]	validation_0-rmse:4.25552
# [400]	validation_0-rmse:4.17006
# [500]	validation_0-rmse:4.14581
# [578]	validation_0-rmse:4.13760
# [0]	validation_0-rmse:20.43655
# [100]	validation_0-rmse:4.61388
# [200]	validation_0-rmse:4.34602
# [264]	validation_0-rmse:4.33444
# [0]	validation_0-rmse:20.74692
# [100]	validation_0-rmse:5.40288
# [200]	validation_0-rmse:4.72536
# [300]	validation_0-rmse:4.57626
# [400]	validation_0-rmse:4.51249
# [500]	validation_0-rmse:4.48699
# [571]	validation_0-rmse:4.48127
# [0]	validation_0-rmse:20.67808
# [100]	validation_0-rmse:5.27858
# [200]	validation_0-rmse:4.57761
# [300]	validation_0-rmse:4.41563
# [376]	validation_0-rmse:4.39385
# [0]	validation_0-rmse:21.32422
# [100]	validation_0-rmse:6.40320
# [200]	validation_0-rmse:5.30195
# [300]	validation_0-rmse:4.86738
# [400]	validation_0-rmse:4.60741
# [500]	validation_0-rmse:4.48378
# [600]	validation_0-rmse:4.41379
# [700]	validation_0-rmse:4.38400
# [800]	validation_0-rmse:4.36445
# [900]	validation_0-rmse:4.35040
# [961]	validation_0-rmse:4.34851
# [0]	validation_0-rmse:21.16669
# [100]	validation_0-rmse:5.30569
# [200]	validation_0-rmse:4.59784
# [300]	validation_0-rmse:4.31144
# [400]	validation_0-rmse:4.20339
# [500]	validation_0-rmse:4.17244
# [600]	validation_0-rmse:4.15466
# [700]	validation_0-rmse:4.15057
# [792]	validation_0-rmse:4.14786
# [0]	validation_0-rmse:21.44315
# [100]	validation_0-rmse:8.59606
# [200]	validation_0-rmse:7.19676
# [300]	validation_0-rmse:6.30058
# [400]	validation_0-rmse:5.76576
# [500]	validation_0-rmse:5.31973
# [600]	validation_0-rmse:5.14278
# [700]	validation_0-rmse:4.97824
# [800]	validation_0-rmse:4.87736
# [900]	validation_0-rmse:4.78746
# [999]	validation_0-rmse:4.72169
# [0]	validation_0-rmse:21.42689
# [100]	validation_0-rmse:8.67641
# [200]	validation_0-rmse:7.19794
# [300]	validation_0-rmse:6.26554
# [400]	validation_0-rmse:5.60910
# [500]	validation_0-rmse:5.25913
# [600]	validation_0-rmse:5.04794
# [700]	validation_0-rmse:4.92262
# [800]	validation_0-rmse:4.82427
# [900]	validation_0-rmse:4.75347
# [1000]	validation_0-rmse:4.66254
# [1100]	validation_0-rmse:4.61621
# [1200]	validation_0-rmse:4.58910
# [1300]	validation_0-rmse:4.56675
# [1310]	validation_0-rmse:4.56121
# [0]	validation_0-rmse:21.16670
# [100]	validation_0-rmse:5.31612
# [200]	validation_0-rmse:4.62646
# [300]	validation_0-rmse:4.39933
# [400]	validation_0-rmse:4.30327
# [500]	validation_0-rmse:4.25913
# [520]	validation_0-rmse:4.26025
# [0]	validation_0-rmse:20.46854
# [100]	validation_0-rmse:4.53104
# [200]	validation_0-rmse:4.27677
# [300]	validation_0-rmse:4.25417
# [328]	validation_0-rmse:4.25812
# [0]	validation_0-rmse:21.73945
# [100]	validation_0-rmse:11.06029
# [200]	validation_0-rmse:7.29545
# [300]	validation_0-rmse:6.01468
# [400]	validation_0-rmse:5.36447
# [500]	validation_0-rmse:5.03770
# [600]	validation_0-rmse:4.86206
# [700]	validation_0-rmse:4.76017
# [800]	validation_0-rmse:4.67509
# [900]	validation_0-rmse:4.60042
# [999]	validation_0-rmse:4.51607
# [0]	validation_0-rmse:21.79244
# [100]	validation_0-rmse:14.50518
# [200]	validation_0-rmse:11.56424
# [300]	validation_0-rmse:10.17482
# [400]	validation_0-rmse:9.32391
# [500]	validation_0-rmse:8.79023
# [600]	validation_0-rmse:8.38004
# [700]	validation_0-rmse:8.11803
# [800]	validation_0-rmse:7.82063
# [900]	validation_0-rmse:7.60076
# [1000]	validation_0-rmse:7.38528
# [1100]	validation_0-rmse:7.20856
# [1200]	validation_0-rmse:7.05078
# [1300]	validation_0-rmse:6.90026
# [1400]	validation_0-rmse:6.76324
# [1500]	validation_0-rmse:6.63805
# [1600]	validation_0-rmse:6.50200
# [1700]	validation_0-rmse:6.35219
# [1800]	validation_0-rmse:6.19410
# [1900]	validation_0-rmse:6.06298
# [1999]	validation_0-rmse:5.94518
# [0]	validation_0-rmse:21.27288
# [100]	validation_0-rmse:6.48125
# [200]	validation_0-rmse:5.33935
# [300]	validation_0-rmse:4.78240
# [400]	validation_0-rmse:4.54048
# [500]	validation_0-rmse:4.38654
# [600]	validation_0-rmse:4.33364
# [700]	validation_0-rmse:4.30607
# [800]	validation_0-rmse:4.27804
# [900]	validation_0-rmse:4.26603
# [1000]	validation_0-rmse:4.25881
# [1016]	validation_0-rmse:4.25687
# [0]	validation_0-rmse:21.76340
# [100]	validation_0-rmse:12.84055
# [200]	validation_0-rmse:9.36775
# [300]	validation_0-rmse:7.88896
# [400]	validation_0-rmse:7.04704
# [500]	validation_0-rmse:6.57448
# [600]	validation_0-rmse:6.21446
# [700]	validation_0-rmse:5.94802
# [800]	validation_0-rmse:5.73866
# [900]	validation_0-rmse:5.55289
# [999]	validation_0-rmse:5.40279
# [0]	validation_0-rmse:21.79243
# [100]	validation_0-rmse:14.50590
# [200]	validation_0-rmse:11.56636
# [300]	validation_0-rmse:10.16809
# [400]	validation_0-rmse:9.39236
# [500]	validation_0-rmse:8.84034
# [600]	validation_0-rmse:8.45451
# [700]	validation_0-rmse:8.16155
# [800]	validation_0-rmse:7.88441
# [900]	validation_0-rmse:7.66858
# [999]	validation_0-rmse:7.46735
# [0]	validation_0-rmse:21.73892
# [100]	validation_0-rmse:11.06169
# [200]	validation_0-rmse:7.30429
# [300]	validation_0-rmse:6.03594
# [400]	validation_0-rmse:5.37538
# [500]	validation_0-rmse:5.03713
# [600]	validation_0-rmse:4.86264
# [700]	validation_0-rmse:4.74533
# [800]	validation_0-rmse:4.65900
# [900]	validation_0-rmse:4.57249
# [999]	validation_0-rmse:4.48349
# [0]	validation_0-rmse:20.97232
# [100]	validation_0-rmse:7.27657
# [200]	validation_0-rmse:5.81790
# [300]	validation_0-rmse:5.27429
# [400]	validation_0-rmse:4.88634
# [500]	validation_0-rmse:4.76335
# [600]	validation_0-rmse:4.67681
# [700]	validation_0-rmse:4.60960
# [800]	validation_0-rmse:4.55205
# [900]	validation_0-rmse:4.51994
# [943]	validation_0-rmse:4.51925
# [0]	validation_0-rmse:20.77272
# [100]	validation_0-rmse:5.41455
# [200]	validation_0-rmse:4.72727
# [300]	validation_0-rmse:4.55073
# [400]	validation_0-rmse:4.53311
# [498]	validation_0-rmse:4.52168
# [0]	validation_0-rmse:20.67792
# [100]	validation_0-rmse:5.43447
# [200]	validation_0-rmse:4.65544
# [300]	validation_0-rmse:4.48758
# [400]	validation_0-rmse:4.41484
# [437]	validation_0-rmse:4.41591
# [0]	validation_0-rmse:21.77289
# [100]	validation_0-rmse:12.45506
# [200]	validation_0-rmse:9.08026
# [300]	validation_0-rmse:7.61156
# [400]	validation_0-rmse:6.88140
# [500]	validation_0-rmse:6.46990
# [600]	validation_0-rmse:6.17316
# [700]	validation_0-rmse:5.90692
# [800]	validation_0-rmse:5.73336
# [900]	validation_0-rmse:5.56074
# [1000]	validation_0-rmse:5.40325
# [1100]	validation_0-rmse:5.27945
# [1200]	validation_0-rmse:5.17860
# [1300]	validation_0-rmse:5.07157
# [1400]	validation_0-rmse:4.98424
# [1500]	validation_0-rmse:4.90885
# [1600]	validation_0-rmse:4.82657
# [1700]	validation_0-rmse:4.77268
# [1800]	validation_0-rmse:4.72627
# [1900]	validation_0-rmse:4.67898
# [1999]	validation_0-rmse:4.64314
# [0]	validation_0-rmse:21.79243
# [100]	validation_0-rmse:14.50625
# [200]	validation_0-rmse:11.57504
# [300]	validation_0-rmse:10.18752
# [400]	validation_0-rmse:9.36077
# [500]	validation_0-rmse:8.79912
# [600]	validation_0-rmse:8.36728
# [700]	validation_0-rmse:8.10475
# [800]	validation_0-rmse:7.82644
# [900]	validation_0-rmse:7.60802
# [999]	validation_0-rmse:7.38984
# [0]	validation_0-rmse:20.43395
# [100]	validation_0-rmse:4.50234
# [200]	validation_0-rmse:4.28440
# [300]	validation_0-rmse:4.26127
# [373]	validation_0-rmse:4.25913
# [0]	validation_0-rmse:21.01254
# [100]	validation_0-rmse:7.17643
# [200]	validation_0-rmse:5.76227
# [300]	validation_0-rmse:5.08750
# [400]	validation_0-rmse:4.87107
# [500]	validation_0-rmse:4.73013
# [600]	validation_0-rmse:4.62801
# [700]	validation_0-rmse:4.58577
# [800]	validation_0-rmse:4.55627
# [852]	validation_0-rmse:4.54372
# [0]	validation_0-rmse:21.31114
# [100]	validation_0-rmse:6.39718
# [200]	validation_0-rmse:5.46531
# [300]	validation_0-rmse:4.93605
# [400]	validation_0-rmse:4.69223
# [500]	validation_0-rmse:4.58252
# [600]	validation_0-rmse:4.51900
# [700]	validation_0-rmse:4.49630
# [800]	validation_0-rmse:4.46876
# [900]	validation_0-rmse:4.45239
# [1000]	validation_0-rmse:4.44385
# [1038]	validation_0-rmse:4.44231
# [0]	validation_0-rmse:21.73945
# [100]	validation_0-rmse:11.06029
# [200]	validation_0-rmse:7.29545
# [300]	validation_0-rmse:6.01468
# [400]	validation_0-rmse:5.36447
# [500]	validation_0-rmse:5.03770
# [600]	validation_0-rmse:4.86206
# [700]	validation_0-rmse:4.76017
# [800]	validation_0-rmse:4.67509
# [900]	validation_0-rmse:4.60042
# [1000]	validation_0-rmse:4.51565
# [1100]	validation_0-rmse:4.45974
# [1200]	validation_0-rmse:4.41542
# [1300]	validation_0-rmse:4.38130
# [1400]	validation_0-rmse:4.34448
# [1500]	validation_0-rmse:4.31301
# [1600]	validation_0-rmse:4.28843
# [1700]	validation_0-rmse:4.26978
# [1800]	validation_0-rmse:4.25368
# [1900]	validation_0-rmse:4.24238
# [1999]	validation_0-rmse:4.23495
# [0]	validation_0-rmse:21.32422
# [100]	validation_0-rmse:6.37960
# [200]	validation_0-rmse:5.40573
# [300]	validation_0-rmse:4.80634
# [400]	validation_0-rmse:4.56988
# [500]	validation_0-rmse:4.45293
# [600]	validation_0-rmse:4.39991
# [625]	validation_0-rmse:4.39781
# [0]	validation_0-rmse:21.32404
# [100]	validation_0-rmse:6.45862
# [200]	validation_0-rmse:5.56938
# [300]	validation_0-rmse:5.03232
# [400]	validation_0-rmse:4.73841
# [500]	validation_0-rmse:4.56091
# [600]	validation_0-rmse:4.49870
# [700]	validation_0-rmse:4.43829
# [800]	validation_0-rmse:4.41646
# [900]	validation_0-rmse:4.38718
# [1000]	validation_0-rmse:4.37370
# [1051]	validation_0-rmse:4.37515
# ✅ XGB 결과: {'Model': 'XGB', 'Line': 4, 'Time(s)': 413.9029893875122, 'RMSE': 4.135203824686545, 'R2': 0.9617195213846317}
#
# 📘 [Line 5] 모델 학습 중...
# [0]	validation_0-rmse:19.90181
# [100]	validation_0-rmse:11.21027
# [200]	validation_0-rmse:8.09648
# [300]	validation_0-rmse:6.71572
# [400]	validation_0-rmse:6.09316
# [500]	validation_0-rmse:5.59149
# [600]	validation_0-rmse:5.27448
# [700]	validation_0-rmse:5.06092
# [800]	validation_0-rmse:4.88011
# [900]	validation_0-rmse:4.74300
# [1000]	validation_0-rmse:4.63407
# [1100]	validation_0-rmse:4.54596
# [1200]	validation_0-rmse:4.47323
# [1300]	validation_0-rmse:4.42651
# [1400]	validation_0-rmse:4.38957
# [1500]	validation_0-rmse:4.35646
# [1600]	validation_0-rmse:4.32961
# [1700]	validation_0-rmse:4.30683
# [1800]	validation_0-rmse:4.29064
# [1900]	validation_0-rmse:4.27679
# [1999]	validation_0-rmse:4.26159
# [0]	validation_0-rmse:19.54255
# [100]	validation_0-rmse:8.31505
# [200]	validation_0-rmse:6.53501
# [300]	validation_0-rmse:5.75870
# [400]	validation_0-rmse:5.24465
# [500]	validation_0-rmse:4.97816
# [600]	validation_0-rmse:4.77853
# [700]	validation_0-rmse:4.65795
# [800]	validation_0-rmse:4.58440
# [900]	validation_0-rmse:4.50512
# [999]	validation_0-rmse:4.47486
# [0]	validation_0-rmse:19.92713
# [100]	validation_0-rmse:13.15971
# [200]	validation_0-rmse:10.61172
# [300]	validation_0-rmse:9.36793
# [400]	validation_0-rmse:8.84626
# [500]	validation_0-rmse:8.23204
# [600]	validation_0-rmse:7.79376
# [700]	validation_0-rmse:7.46376
# [800]	validation_0-rmse:7.12544
# [900]	validation_0-rmse:6.85863
# [999]	validation_0-rmse:6.63570
# [0]	validation_0-rmse:19.42084
# [100]	validation_0-rmse:5.64517
# [200]	validation_0-rmse:4.67666
# [300]	validation_0-rmse:4.38276
# [400]	validation_0-rmse:4.28757
# [500]	validation_0-rmse:4.25346
# [600]	validation_0-rmse:4.23544
# [700]	validation_0-rmse:4.21588
# [800]	validation_0-rmse:4.20643
# [819]	validation_0-rmse:4.20520
# [0]	validation_0-rmse:18.78062
# [100]	validation_0-rmse:4.78187
# [200]	validation_0-rmse:4.41779
# [300]	validation_0-rmse:4.35046
# [400]	validation_0-rmse:4.32393
# [500]	validation_0-rmse:4.30930
# [600]	validation_0-rmse:4.30122
# [634]	validation_0-rmse:4.30115
# [0]	validation_0-rmse:18.89622
# [100]	validation_0-rmse:5.16398
# [200]	validation_0-rmse:4.43573
# [300]	validation_0-rmse:4.24833
# [400]	validation_0-rmse:4.22489
# [414]	validation_0-rmse:4.22472
# [0]	validation_0-rmse:18.96629
# [100]	validation_0-rmse:5.40780
# [200]	validation_0-rmse:4.61537
# [300]	validation_0-rmse:4.44877
# [400]	validation_0-rmse:4.39344
# [496]	validation_0-rmse:4.37614
# [0]	validation_0-rmse:19.45729
# [100]	validation_0-rmse:6.68497
# [200]	validation_0-rmse:5.23847
# [300]	validation_0-rmse:4.70760
# [400]	validation_0-rmse:4.49442
# [500]	validation_0-rmse:4.36285
# [600]	validation_0-rmse:4.27197
# [700]	validation_0-rmse:4.23768
# [800]	validation_0-rmse:4.21351
# [900]	validation_0-rmse:4.18761
# [999]	validation_0-rmse:4.17770
# [0]	validation_0-rmse:19.42084
# [100]	validation_0-rmse:5.77665
# [200]	validation_0-rmse:4.71479
# [300]	validation_0-rmse:4.42324
# [400]	validation_0-rmse:4.32465
# [500]	validation_0-rmse:4.28916
# [590]	validation_0-rmse:4.27611
# [0]	validation_0-rmse:19.52795
# [100]	validation_0-rmse:7.88754
# [200]	validation_0-rmse:6.36436
# [300]	validation_0-rmse:5.46664
# [400]	validation_0-rmse:5.00780
# [500]	validation_0-rmse:4.72976
# [600]	validation_0-rmse:4.55641
# [700]	validation_0-rmse:4.43489
# [800]	validation_0-rmse:4.31969
# [900]	validation_0-rmse:4.25506
# [999]	validation_0-rmse:4.20581
# [0]	validation_0-rmse:19.54254
# [100]	validation_0-rmse:8.49123
# [200]	validation_0-rmse:6.70974
# [300]	validation_0-rmse:5.82179
# [400]	validation_0-rmse:5.31432
# [500]	validation_0-rmse:5.05020
# [600]	validation_0-rmse:4.80812
# [700]	validation_0-rmse:4.66582
# [800]	validation_0-rmse:4.58657
# [900]	validation_0-rmse:4.52719
# [1000]	validation_0-rmse:4.47369
# [1100]	validation_0-rmse:4.44829
# [1108]	validation_0-rmse:4.44616
# [0]	validation_0-rmse:19.42084
# [100]	validation_0-rmse:5.66683
# [200]	validation_0-rmse:4.69839
# [300]	validation_0-rmse:4.38911
# [400]	validation_0-rmse:4.30407
# [500]	validation_0-rmse:4.26759
# [600]	validation_0-rmse:4.25030
# [700]	validation_0-rmse:4.23330
# [800]	validation_0-rmse:4.22116
# [900]	validation_0-rmse:4.21536
# [1000]	validation_0-rmse:4.20964
# [1100]	validation_0-rmse:4.20477
# [1200]	validation_0-rmse:4.20241
# [1229]	validation_0-rmse:4.20388
# [0]	validation_0-rmse:18.78128
# [100]	validation_0-rmse:4.70912
# [200]	validation_0-rmse:4.36084
# [300]	validation_0-rmse:4.31965
# [400]	validation_0-rmse:4.30489
# [458]	validation_0-rmse:4.30202
# [0]	validation_0-rmse:19.90174
# [100]	validation_0-rmse:11.19907
# [200]	validation_0-rmse:8.08265
# [300]	validation_0-rmse:6.67623
# [400]	validation_0-rmse:6.05318
# [500]	validation_0-rmse:5.58334
# [600]	validation_0-rmse:5.25655
# [700]	validation_0-rmse:5.03563
# [800]	validation_0-rmse:4.86458
# [900]	validation_0-rmse:4.74107
# [999]	validation_0-rmse:4.61993
# [0]	validation_0-rmse:19.92714
# [100]	validation_0-rmse:13.15978
# [200]	validation_0-rmse:10.55907
# [300]	validation_0-rmse:9.37007
# [400]	validation_0-rmse:8.83260
# [500]	validation_0-rmse:8.21797
# [600]	validation_0-rmse:7.77208
# [700]	validation_0-rmse:7.41093
# [800]	validation_0-rmse:7.09575
# [900]	validation_0-rmse:6.82172
# [1000]	validation_0-rmse:6.56454
# [1100]	validation_0-rmse:6.31146
# [1200]	validation_0-rmse:6.11853
# [1300]	validation_0-rmse:5.95804
# [1400]	validation_0-rmse:5.83377
# [1500]	validation_0-rmse:5.74244
# [1600]	validation_0-rmse:5.64233
# [1700]	validation_0-rmse:5.54663
# [1800]	validation_0-rmse:5.46788
# [1900]	validation_0-rmse:5.39463
# [1999]	validation_0-rmse:5.33830
# [0]	validation_0-rmse:19.49262
# [100]	validation_0-rmse:6.61316
# [200]	validation_0-rmse:5.11776
# [300]	validation_0-rmse:4.59433
# [400]	validation_0-rmse:4.38479
# [500]	validation_0-rmse:4.23244
# [600]	validation_0-rmse:4.16461
# [700]	validation_0-rmse:4.13377
# [800]	validation_0-rmse:4.10941
# [900]	validation_0-rmse:4.08795
# [1000]	validation_0-rmse:4.07036
# [1041]	validation_0-rmse:4.07786
# [0]	validation_0-rmse:19.92007
# [100]	validation_0-rmse:11.98720
# [200]	validation_0-rmse:9.19478
# [300]	validation_0-rmse:7.86446
# [400]	validation_0-rmse:7.33587
# [500]	validation_0-rmse:6.77744
# [600]	validation_0-rmse:6.34229
# [700]	validation_0-rmse:5.99021
# [800]	validation_0-rmse:5.69816
# [900]	validation_0-rmse:5.45031
# [999]	validation_0-rmse:5.27013
# [0]	validation_0-rmse:19.92713
# [100]	validation_0-rmse:13.16034
# [200]	validation_0-rmse:10.58607
# [300]	validation_0-rmse:9.31768
# [400]	validation_0-rmse:8.75404
# [500]	validation_0-rmse:8.18223
# [600]	validation_0-rmse:7.72394
# [700]	validation_0-rmse:7.36858
# [800]	validation_0-rmse:7.03558
# [900]	validation_0-rmse:6.76966
# [999]	validation_0-rmse:6.51510
# [0]	validation_0-rmse:19.90163
# [100]	validation_0-rmse:11.20783
# [200]	validation_0-rmse:8.10713
# [300]	validation_0-rmse:6.75240
# [400]	validation_0-rmse:6.09218
# [500]	validation_0-rmse:5.62899
# [600]	validation_0-rmse:5.32289
# [700]	validation_0-rmse:5.11279
# [800]	validation_0-rmse:4.92339
# [900]	validation_0-rmse:4.79135
# [999]	validation_0-rmse:4.66526
# [0]	validation_0-rmse:19.03723
# [100]	validation_0-rmse:6.49007
# [200]	validation_0-rmse:5.18468
# [300]	validation_0-rmse:4.82417
# [400]	validation_0-rmse:4.66678
# [500]	validation_0-rmse:4.55978
# [558]	validation_0-rmse:4.54742
# [0]	validation_0-rmse:18.89562
# [100]	validation_0-rmse:5.03016
# [200]	validation_0-rmse:4.40258
# [300]	validation_0-rmse:4.28005
# [400]	validation_0-rmse:4.24088
# [462]	validation_0-rmse:4.25030
# [0]	validation_0-rmse:18.96635
# [100]	validation_0-rmse:5.32027
# [200]	validation_0-rmse:4.71517
# [300]	validation_0-rmse:4.55485
# [400]	validation_0-rmse:4.52540
# [414]	validation_0-rmse:4.52202
# [0]	validation_0-rmse:19.91307
# [100]	validation_0-rmse:12.03218
# [200]	validation_0-rmse:9.17561
# [300]	validation_0-rmse:7.80865
# [400]	validation_0-rmse:7.21587
# [500]	validation_0-rmse:6.60074
# [600]	validation_0-rmse:6.17400
# [700]	validation_0-rmse:5.87477
# [800]	validation_0-rmse:5.58867
# [900]	validation_0-rmse:5.34710
# [1000]	validation_0-rmse:5.14723
# [1100]	validation_0-rmse:5.00272
# [1200]	validation_0-rmse:4.88597
# [1300]	validation_0-rmse:4.79407
# [1400]	validation_0-rmse:4.70094
# [1500]	validation_0-rmse:4.63736
# [1600]	validation_0-rmse:4.57133
# [1700]	validation_0-rmse:4.51111
# [1800]	validation_0-rmse:4.46680
# [1900]	validation_0-rmse:4.42274
# [1999]	validation_0-rmse:4.38673
# [0]	validation_0-rmse:19.92713
# [100]	validation_0-rmse:13.16031
# [200]	validation_0-rmse:10.56114
# [300]	validation_0-rmse:9.32474
# [400]	validation_0-rmse:8.73820
# [500]	validation_0-rmse:8.15175
# [600]	validation_0-rmse:7.71835
# [700]	validation_0-rmse:7.35269
# [800]	validation_0-rmse:6.99031
# [900]	validation_0-rmse:6.74017
# [999]	validation_0-rmse:6.50937
# [0]	validation_0-rmse:18.77964
# [100]	validation_0-rmse:4.77482
# [200]	validation_0-rmse:4.43031
# [300]	validation_0-rmse:4.36826
# [400]	validation_0-rmse:4.35088
# [500]	validation_0-rmse:4.34115
# [600]	validation_0-rmse:4.33446
# [700]	validation_0-rmse:4.33219
# [800]	validation_0-rmse:4.32922
# [826]	validation_0-rmse:4.32905
# [0]	validation_0-rmse:19.03753
# [100]	validation_0-rmse:6.61610
# [200]	validation_0-rmse:5.19137
# [300]	validation_0-rmse:4.62906
# [400]	validation_0-rmse:4.42693
# [500]	validation_0-rmse:4.35657
# [596]	validation_0-rmse:4.30982
# [0]	validation_0-rmse:19.45757
# [100]	validation_0-rmse:6.56218
# [200]	validation_0-rmse:5.21075
# [300]	validation_0-rmse:4.66648
# [400]	validation_0-rmse:4.39875
# [500]	validation_0-rmse:4.22572
# [600]	validation_0-rmse:4.16292
# [700]	validation_0-rmse:4.13032
# [800]	validation_0-rmse:4.09840
# [900]	validation_0-rmse:4.07394
# [1000]	validation_0-rmse:4.05894
# [1100]	validation_0-rmse:4.04810
# [1200]	validation_0-rmse:4.04228
# [1300]	validation_0-rmse:4.03331
# [1400]	validation_0-rmse:4.02652
# [1500]	validation_0-rmse:4.01957
# [1540]	validation_0-rmse:4.02000
# [0]	validation_0-rmse:19.90174
# [100]	validation_0-rmse:11.19907
# [200]	validation_0-rmse:8.08265
# [300]	validation_0-rmse:6.67623
# [400]	validation_0-rmse:6.05318
# [500]	validation_0-rmse:5.58334
# [600]	validation_0-rmse:5.25655
# [700]	validation_0-rmse:5.03563
# [800]	validation_0-rmse:4.86458
# [900]	validation_0-rmse:4.74107
# [1000]	validation_0-rmse:4.61793
# [1100]	validation_0-rmse:4.52307
# [1200]	validation_0-rmse:4.44414
# [1300]	validation_0-rmse:4.38410
# [1400]	validation_0-rmse:4.34826
# [1500]	validation_0-rmse:4.31431
# [1600]	validation_0-rmse:4.29359
# [1700]	validation_0-rmse:4.27181
# ...
# [500]	validation_0-rmse:6.60187
# [600]	validation_0-rmse:6.39989
# [700]	validation_0-rmse:6.28449
# [800]	validation_0-rmse:6.21209
# [900]	validation_0-rmse:6.12660
# [999]	validation_0-rmse:6.04970
# [0]	validation_0-rmse:23.35347
# [100]	validation_0-rmse:10.01197
# [200]	validation_0-rmse:8.25098
# [300]	validation_0-rmse:7.47255
# [400]	validation_0-rmse:6.96309
# [500]	validation_0-rmse:6.62963
# [600]	validation_0-rmse:6.43937
# [700]	validation_0-rmse:6.30785
# [800]	validation_0-rmse:6.17256
# [900]	validation_0-rmse:6.07931
# [1000]	validation_0-rmse:5.96779
# [1070]	validation_0-rmse:5.91425
# [0]	validation_0-rmse:23.08598
# [100]	validation_0-rmse:6.67162
# [200]	validation_0-rmse:6.04073
# [300]	validation_0-rmse:5.90436
# [400]	validation_0-rmse:5.85248
# [439]	validation_0-rmse:5.86224
# [0]	validation_0-rmse:22.47126
# [100]	validation_0-rmse:6.17597
# [200]	validation_0-rmse:6.01701
# [243]	validation_0-rmse:5.98757
# [0]	validation_0-rmse:23.60595
# [100]	validation_0-rmse:13.39239
# [200]	validation_0-rmse:9.56016
# [300]	validation_0-rmse:7.63147
# [400]	validation_0-rmse:6.90815
# [500]	validation_0-rmse:6.55631
# [600]	validation_0-rmse:6.38320
# [700]	validation_0-rmse:6.22867
# [800]	validation_0-rmse:6.11398
# [900]	validation_0-rmse:6.04262
# [999]	validation_0-rmse:5.99306
# [0]	validation_0-rmse:23.65790
# [100]	validation_0-rmse:17.26157
# [200]	validation_0-rmse:13.77020
# [300]	validation_0-rmse:11.89340
# [400]	validation_0-rmse:10.84908
# [500]	validation_0-rmse:10.15913
# [600]	validation_0-rmse:9.65418
# [700]	validation_0-rmse:9.17808
# [800]	validation_0-rmse:8.83241
# [900]	validation_0-rmse:8.57023
# [1000]	validation_0-rmse:8.39730
# [1100]	validation_0-rmse:8.19680
# [1200]	validation_0-rmse:8.04502
# [1300]	validation_0-rmse:7.89709
# [1400]	validation_0-rmse:7.74741
# [1500]	validation_0-rmse:7.63747
# [1600]	validation_0-rmse:7.50590
# [1700]	validation_0-rmse:7.38262
# [1800]	validation_0-rmse:7.27142
# [1900]	validation_0-rmse:7.15985
# [1999]	validation_0-rmse:7.07104
# [0]	validation_0-rmse:23.21858
# [100]	validation_0-rmse:8.05749
# [200]	validation_0-rmse:6.74458
# [300]	validation_0-rmse:6.25984
# [400]	validation_0-rmse:6.03353
# [500]	validation_0-rmse:5.93521
# [600]	validation_0-rmse:5.87269
# [700]	validation_0-rmse:5.82593
# [800]	validation_0-rmse:5.77541
# [900]	validation_0-rmse:5.74245
# [911]	validation_0-rmse:5.74089
# [0]	validation_0-rmse:23.63015
# [100]	validation_0-rmse:15.46967
# [200]	validation_0-rmse:11.82033
# [300]	validation_0-rmse:9.50433
# [400]	validation_0-rmse:8.42916
# [500]	validation_0-rmse:7.93795
# [600]	validation_0-rmse:7.54367
# [700]	validation_0-rmse:7.21835
# [800]	validation_0-rmse:6.98886
# [900]	validation_0-rmse:6.81502
# [999]	validation_0-rmse:6.66294
# [0]	validation_0-rmse:23.65791
# [100]	validation_0-rmse:17.26483
# [200]	validation_0-rmse:13.76925
# [300]	validation_0-rmse:11.81216
# [400]	validation_0-rmse:10.75524
# [500]	validation_0-rmse:10.02651
# [600]	validation_0-rmse:9.56580
# [700]	validation_0-rmse:9.07732
# [800]	validation_0-rmse:8.74229
# [900]	validation_0-rmse:8.54646
# [999]	validation_0-rmse:8.35333
# [0]	validation_0-rmse:23.60593
# [100]	validation_0-rmse:13.42555
# [200]	validation_0-rmse:9.58160
# [300]	validation_0-rmse:7.62877
# [400]	validation_0-rmse:6.90415
# [500]	validation_0-rmse:6.54709
# [600]	validation_0-rmse:6.36100
# [700]	validation_0-rmse:6.21579
# [800]	validation_0-rmse:6.11423
# [900]	validation_0-rmse:6.04425
# [999]	validation_0-rmse:6.00009
# [0]	validation_0-rmse:22.99105
# [100]	validation_0-rmse:7.90752
# [200]	validation_0-rmse:6.90419
# [300]	validation_0-rmse:6.33185
# [400]	validation_0-rmse:6.10355
# [500]	validation_0-rmse:5.96251
# [545]	validation_0-rmse:5.95805
# [0]	validation_0-rmse:22.63209
# [100]	validation_0-rmse:6.67250
# [200]	validation_0-rmse:6.09597
# [300]	validation_0-rmse:5.99988
# [327]	validation_0-rmse:6.02097
# [0]	validation_0-rmse:22.71608
# [100]	validation_0-rmse:6.68212
# [200]	validation_0-rmse:6.03978
# [300]	validation_0-rmse:5.82265
# [400]	validation_0-rmse:5.67228
# [428]	validation_0-rmse:5.68158
# [0]	validation_0-rmse:23.62175
# [100]	validation_0-rmse:15.21261
# [200]	validation_0-rmse:11.32159
# [300]	validation_0-rmse:9.18828
# [400]	validation_0-rmse:8.28980
# [500]	validation_0-rmse:7.77739
# [600]	validation_0-rmse:7.32246
# [700]	validation_0-rmse:7.05233
# [800]	validation_0-rmse:6.84398
# [900]	validation_0-rmse:6.67996
# [1000]	validation_0-rmse:6.54940
# [1100]	validation_0-rmse:6.43016
# [1200]	validation_0-rmse:6.33666
# [1300]	validation_0-rmse:6.26051
# [1400]	validation_0-rmse:6.18274
# [1500]	validation_0-rmse:6.13240
# [1600]	validation_0-rmse:6.08248
# [1700]	validation_0-rmse:6.04708
# [1800]	validation_0-rmse:6.00339
# [1900]	validation_0-rmse:5.96254
# [1999]	validation_0-rmse:5.93342
# [0]	validation_0-rmse:23.65791
# [100]	validation_0-rmse:17.26481
# [200]	validation_0-rmse:13.74226
# [300]	validation_0-rmse:11.90102
# [400]	validation_0-rmse:10.86691
# [500]	validation_0-rmse:10.22999
# [600]	validation_0-rmse:9.72397
# [700]	validation_0-rmse:9.18180
# [800]	validation_0-rmse:8.83371
# [900]	validation_0-rmse:8.58732
# [999]	validation_0-rmse:8.38814
# [0]	validation_0-rmse:22.47320
# [100]	validation_0-rmse:6.22391
# [200]	validation_0-rmse:6.02491
# [249]	validation_0-rmse:6.02722
# [0]	validation_0-rmse:22.98919
# [100]	validation_0-rmse:8.38839
# [200]	validation_0-rmse:7.28265
# [300]	validation_0-rmse:6.62806
# [400]	validation_0-rmse:6.29983
# [500]	validation_0-rmse:6.07774
# [600]	validation_0-rmse:5.93245
# [700]	validation_0-rmse:5.87471
# [773]	validation_0-rmse:5.86910
# [0]	validation_0-rmse:23.17646
# [100]	validation_0-rmse:7.83808
# [200]	validation_0-rmse:6.58157
# [300]	validation_0-rmse:6.17207
# [400]	validation_0-rmse:5.97796
# [500]	validation_0-rmse:5.87208
# [600]	validation_0-rmse:5.81193
# [700]	validation_0-rmse:5.78064
# [772]	validation_0-rmse:5.77711
# [0]	validation_0-rmse:23.60595
# [100]	validation_0-rmse:13.39239
# [200]	validation_0-rmse:9.56016
# [300]	validation_0-rmse:7.63147
# [400]	validation_0-rmse:6.90815
# [500]	validation_0-rmse:6.55631
# [600]	validation_0-rmse:6.38320
# [700]	validation_0-rmse:6.22867
# [800]	validation_0-rmse:6.11398
# [900]	validation_0-rmse:6.04262
# [1000]	validation_0-rmse:5.99285
# [1100]	validation_0-rmse:5.95072
# [1200]	validation_0-rmse:5.91174
# [1300]	validation_0-rmse:5.88396
# [1400]	validation_0-rmse:5.86637
# [1500]	validation_0-rmse:5.85254
# [1600]	validation_0-rmse:5.83897
# [1700]	validation_0-rmse:5.83067
# [1800]	validation_0-rmse:5.82188
# [1900]	validation_0-rmse:5.81654
# [1999]	validation_0-rmse:5.81086
# [0]	validation_0-rmse:23.17670
# [100]	validation_0-rmse:7.79772
# [200]	validation_0-rmse:6.58707
# [300]	validation_0-rmse:6.15218
# [400]	validation_0-rmse:5.95123
# [500]	validation_0-rmse:5.87560
# [600]	validation_0-rmse:5.78121
# [700]	validation_0-rmse:5.76110
# [800]	validation_0-rmse:5.72208
# [813]	validation_0-rmse:5.72311
# [0]	validation_0-rmse:23.17666
# [100]	validation_0-rmse:7.98587
# [200]	validation_0-rmse:6.64604
# [300]	validation_0-rmse:6.20655
# [400]	validation_0-rmse:6.01955
# [500]	validation_0-rmse:5.87043
# [600]	validation_0-rmse:5.79318
# [689]	validation_0-rmse:5.77937
# ✅ XGB 결과: {'Model': 'XGB', 'Line': 7, 'Time(s)': 450.59627747535706, 'RMSE': 5.66897326628194, 'R2': 0.9385557871573218}
#
# 📘 [Line 8] 모델 학습 중...
# [0]	validation_0-rmse:23.56023
# [100]	validation_0-rmse:10.82098
# [200]	validation_0-rmse:6.66328
# [300]	validation_0-rmse:5.29127
# [400]	validation_0-rmse:4.64593
# [500]	validation_0-rmse:4.41421
# [600]	validation_0-rmse:4.31332
# [700]	validation_0-rmse:4.24025
# [800]	validation_0-rmse:4.18249
# [900]	validation_0-rmse:4.14261
# [1000]	validation_0-rmse:4.12120
# [1100]	validation_0-rmse:4.10184
# [1200]	validation_0-rmse:4.09165
# [1300]	validation_0-rmse:4.08761
# [1400]	validation_0-rmse:4.08533
# [1500]	validation_0-rmse:4.08145
# [1591]	validation_0-rmse:4.07953
# [0]	validation_0-rmse:22.95707
# [100]	validation_0-rmse:6.28156
# [200]	validation_0-rmse:4.91246
# [300]	validation_0-rmse:4.49795
# [400]	validation_0-rmse:4.31700
# [500]	validation_0-rmse:4.22512
# [600]	validation_0-rmse:4.18094
# [669]	validation_0-rmse:4.17585
# [0]	validation_0-rmse:23.61013
# [100]	validation_0-rmse:13.43587
# [200]	validation_0-rmse:9.27452
# [300]	validation_0-rmse:7.48601
# [400]	validation_0-rmse:6.89069
# [500]	validation_0-rmse:6.44662
# [600]	validation_0-rmse:5.91156
# [700]	validation_0-rmse:5.51449
# [800]	validation_0-rmse:5.26590
# [900]	validation_0-rmse:5.06555
# [999]	validation_0-rmse:4.93125
# [0]	validation_0-rmse:22.72243
# [100]	validation_0-rmse:4.45967
# [200]	validation_0-rmse:4.13730
# [300]	validation_0-rmse:4.10325
# [385]	validation_0-rmse:4.09442
# [0]	validation_0-rmse:21.61443
# [100]	validation_0-rmse:4.29808
# [178]	validation_0-rmse:4.27002
# [0]	validation_0-rmse:21.86368
# [100]	validation_0-rmse:4.17977
# [182]	validation_0-rmse:4.09431
# [0]	validation_0-rmse:21.91558
# [100]	validation_0-rmse:4.28817
# [200]	validation_0-rmse:4.18905
# [297]	validation_0-rmse:4.17503
# [0]	validation_0-rmse:22.85022
# [100]	validation_0-rmse:4.99323
# [200]	validation_0-rmse:4.16084
# [300]	validation_0-rmse:4.01807
# [400]	validation_0-rmse:3.95844
# [500]	validation_0-rmse:3.94175
# [600]	validation_0-rmse:3.92990
# [644]	validation_0-rmse:3.92950
# [0]	validation_0-rmse:22.72283
# [100]	validation_0-rmse:4.49353
# [200]	validation_0-rmse:4.22383
# [300]	validation_0-rmse:4.17648
# [400]	validation_0-rmse:4.16214
# [417]	validation_0-rmse:4.16190
# [0]	validation_0-rmse:22.94772
# [100]	validation_0-rmse:6.47947
# [200]	validation_0-rmse:4.95246
# [300]	validation_0-rmse:4.59221
# [400]	validation_0-rmse:4.43728
# [500]	validation_0-rmse:4.34594
# [600]	validation_0-rmse:4.28369
# [700]	validation_0-rmse:4.24976
# [800]	validation_0-rmse:4.20801
# [900]	validation_0-rmse:4.18710
# [999]	validation_0-rmse:4.17183
# [0]	validation_0-rmse:22.95701
# [100]	validation_0-rmse:6.37095
# [200]	validation_0-rmse:5.04709
# [300]	validation_0-rmse:4.57215
# [400]	validation_0-rmse:4.41769
# [500]	validation_0-rmse:4.34378
# [568]	validation_0-rmse:4.32442
# [0]	validation_0-rmse:22.72283
# [100]	validation_0-rmse:4.52430
# [200]	validation_0-rmse:4.22081
# [300]	validation_0-rmse:4.16516
# [396]	validation_0-rmse:4.15258
# [0]	validation_0-rmse:21.63947
# [100]	validation_0-rmse:4.34271
# [200]	validation_0-rmse:4.32708
# [300]	validation_0-rmse:4.32089
# [332]	validation_0-rmse:4.32119
# [0]	validation_0-rmse:23.55771
# [100]	validation_0-rmse:10.79382
# [200]	validation_0-rmse:6.67233
# [300]	validation_0-rmse:5.24561
# [400]	validation_0-rmse:4.59826
# [500]	validation_0-rmse:4.38658
# [600]	validation_0-rmse:4.29387
# [700]	validation_0-rmse:4.24391
# [800]	validation_0-rmse:4.18233
# [900]	validation_0-rmse:4.14413
# [999]	validation_0-rmse:4.12261
# [0]	validation_0-rmse:23.61013
# [100]	validation_0-rmse:13.43575
# [200]	validation_0-rmse:9.26532
# [300]	validation_0-rmse:7.47575
# [400]	validation_0-rmse:6.86466
# [500]	validation_0-rmse:6.44169
# [600]	validation_0-rmse:5.92678
# [700]	validation_0-rmse:5.56831
# [800]	validation_0-rmse:5.31601
# [900]	validation_0-rmse:5.10731
# [1000]	validation_0-rmse:4.96996
# [1100]	validation_0-rmse:4.85851
# [1200]	validation_0-rmse:4.77759
# [1300]	validation_0-rmse:4.70473
# [1400]	validation_0-rmse:4.65672
# [1500]	validation_0-rmse:4.58382
# [1600]	validation_0-rmse:4.53093
# [1700]	validation_0-rmse:4.50410
# [1800]	validation_0-rmse:4.47628
# [1900]	validation_0-rmse:4.44804
# [1999]	validation_0-rmse:4.42307
# [0]	validation_0-rmse:22.84123
# [100]	validation_0-rmse:5.15537
# [200]	validation_0-rmse:4.33507
# [300]	validation_0-rmse:4.21121
# [400]	validation_0-rmse:4.16217
# [500]	validation_0-rmse:4.14497
# [600]	validation_0-rmse:4.12383
# [700]	validation_0-rmse:4.10830
# [750]	validation_0-rmse:4.10598
# [0]	validation_0-rmse:23.58737
# [100]	validation_0-rmse:12.08383
# [200]	validation_0-rmse:7.81040
# [300]	validation_0-rmse:6.03490
# [400]	validation_0-rmse:5.42798
# [500]	validation_0-rmse:4.97782
# [600]	validation_0-rmse:4.74318
# [700]	validation_0-rmse:4.55873
# [800]	validation_0-rmse:4.39397
# [900]	validation_0-rmse:4.28714
# [999]	validation_0-rmse:4.21690
# [0]	validation_0-rmse:23.61014
# [100]	validation_0-rmse:13.43120
# [200]	validation_0-rmse:9.26858
# [300]	validation_0-rmse:7.50089
# [400]	validation_0-rmse:6.88851
# [500]	validation_0-rmse:6.44490
# [600]	validation_0-rmse:5.94968
# [700]	validation_0-rmse:5.58235
# [800]	validation_0-rmse:5.32384
# [900]	validation_0-rmse:5.14207
# [999]	validation_0-rmse:5.02765
# [0]	validation_0-rmse:23.55824
# [100]	validation_0-rmse:10.80511
# [200]	validation_0-rmse:6.68516
# [300]	validation_0-rmse:5.28374
# [400]	validation_0-rmse:4.63830
# [500]	validation_0-rmse:4.43739
# [600]	validation_0-rmse:4.32460
# [700]	validation_0-rmse:4.25902
# [800]	validation_0-rmse:4.19610
# [900]	validation_0-rmse:4.15507
# [999]	validation_0-rmse:4.13211
# [0]	validation_0-rmse:22.14535
# [100]	validation_0-rmse:4.60169
# [200]	validation_0-rmse:4.21854
# [300]	validation_0-rmse:4.09545
# [0]	validation_0-rmse:21.93162
# [100]	validation_0-rmse:4.36551
# [200]	validation_0-rmse:4.23137
# [240]	validation_0-rmse:4.22767
# [0]	validation_0-rmse:21.91557
# [100]	validation_0-rmse:4.52832
# [200]	validation_0-rmse:4.35865
# [278]	validation_0-rmse:4.34407
# [0]	validation_0-rmse:23.58201
# [100]	validation_0-rmse:11.88094
# [200]	validation_0-rmse:7.73914
# [300]	validation_0-rmse:6.06259
# [400]	validation_0-rmse:5.40249
# [500]	validation_0-rmse:4.93095
# [600]	validation_0-rmse:4.66538
# [700]	validation_0-rmse:4.41275
# [800]	validation_0-rmse:4.28598
# [900]	validation_0-rmse:4.19920
# [1000]	validation_0-rmse:4.15182
# [1100]	validation_0-rmse:4.11339
# [1200]	validation_0-rmse:4.08566
# [1300]	validation_0-rmse:4.07078
# [1400]	validation_0-rmse:4.05624
# [1500]	validation_0-rmse:4.04541
# [1600]	validation_0-rmse:4.03597
# [1700]	validation_0-rmse:4.02855
# [1800]	validation_0-rmse:4.02194
# [1900]	validation_0-rmse:4.01557
# [1999]	validation_0-rmse:4.01254
# [0]	validation_0-rmse:23.61014
# [100]	validation_0-rmse:13.43121
# [200]	validation_0-rmse:9.25963
# [300]	validation_0-rmse:7.49635
# [400]	validation_0-rmse:6.86262
# [500]	validation_0-rmse:6.44825
# [600]	validation_0-rmse:5.90841
# [700]	validation_0-rmse:5.54415
# [800]	validation_0-rmse:5.28318
# [900]	validation_0-rmse:5.08057
# [999]	validation_0-rmse:4.95710
# [0]	validation_0-rmse:21.61941
# [100]	validation_0-rmse:4.26517
# [200]	validation_0-rmse:4.21924
# [300]	validation_0-rmse:4.21155
# [390]	validation_0-rmse:4.20929
# [0]	validation_0-rmse:22.12917
# [100]	validation_0-rmse:4.91781
# [200]	validation_0-rmse:4.43976
# [300]	validation_0-rmse:4.30758
# [362]	validation_0-rmse:4.29244
# [0]	validation_0-rmse:22.81585
# [100]	validation_0-rmse:5.04218
# [200]	validation_0-rmse:4.16524
# [300]	validation_0-rmse:4.07246
# [400]	validation_0-rmse:4.04125
# [459]	validation_0-rmse:4.03385
# [0]	validation_0-rmse:23.55771
# [100]	validation_0-rmse:10.79382
# [200]	validation_0-rmse:6.67233
# [300]	validation_0-rmse:5.24561
# [400]	validation_0-rmse:4.59826
# [500]	validation_0-rmse:4.38658
# [600]	validation_0-rmse:4.29387
# [700]	validation_0-rmse:4.24391
# [800]	validation_0-rmse:4.18233
# [900]	validation_0-rmse:4.14413
# [1000]	validation_0-rmse:4.12268
# [1100]	validation_0-rmse:4.10393
# [1200]	validation_0-rmse:4.09375
# [1300]	validation_0-rmse:4.08451
# [1400]	validation_0-rmse:4.08051
# [1416]	validation_0-rmse:4.08043
# [0]	validation_0-rmse:22.85022
# [100]	validation_0-rmse:4.95817
# [200]	validation_0-rmse:4.10902
# [300]	validation_0-rmse:4.00527
# [400]	validation_0-rmse:3.95819
# [500]	validation_0-rmse:3.94144
# [600]	validation_0-rmse:3.92960
# [700]	validation_0-rmse:3.92554
# [800]	validation_0-rmse:3.91374
# [890]	validation_0-rmse:3.91115
# [0]	validation_0-rmse:22.81330
# [100]	validation_0-rmse:5.03338
# [200]	validation_0-rmse:4.22510
# [300]	validation_0-rmse:4.10575
# [400]	validation_0-rmse:4.05877
# [500]	validation_0-rmse:4.04149
# [600]	validation_0-rmse:4.03107
# [650]	validation_0-rmse:4.02915
# ✅ XGB 결과: {'Model': 'XGB', 'Line': 8, 'Time(s)': 220.86828231811523, 'RMSE': 3.910140889008282, 'R2': 0.9722978544488722}
#
# 📊 전체 성능 요약:
#   Model  Line     Time(s)      RMSE        R2
# 0   XGB     1  712.767521  4.042834  0.961140
# 1   XGB     2  306.136961  7.401647  0.880418
# 2   XGB     3  372.653760  4.214566  0.954877
# 3   XGB     4  413.902989  4.135204  0.961720
# 4   XGB     5  890.726070  4.019022  0.957153
# 5   XGB     6  351.186032  4.625868  0.913664
# 6   XGB     7  450.596277  5.668973  0.938556
# 7   XGB     8  220.868282  3.910141  0.972298

# %%
gap = pd.read_csv('./test/250206-xgb.csv') # 내 데터터
gap.shape

import os
제출 = pd.read_csv('./test/minjeong.csv') # 민정언니 데이터

import numpy as np

# 마스크 생성
from sklearn.metrics import root_mean_squared_error
rmse = mean_squared_error(
    제출['Congestion'],
    gap['Congestion'],
    squared=False      # squared=False 하면 RMSE 를 직접 계산해 줌
)

print(f"RMSE: {rmse:.4f}")
# Out:
# RMSE: 4.3790

# %%
import joblib
import os
import pandas as pd

best_params_summary = []

for line in range(1, 9):  
    model_path = f'./models/xgb_line{line}.pkl'
    if os.path.exists(model_path):
        model = joblib.load(model_path)
        params = model.get_params()
        best_params_summary.append({
            'Line': line,
            **{k: v for k, v in params.items() if k in param_grid}
        })

# 결과 보기
df_params = pd.DataFrame(best_params_summary)
df_params
# Out:
#    Line  colsample_bytree  gamma  learning_rate  max_depth  min_child_weight  \
# 0     1               0.8    0.0           0.05         12                 3
# 1     2               0.9    0.5           0.05          8                 1
# 2     3               0.8    0.0           0.05         10                 1
# 3     4               0.8    0.0           0.05         12                 3
# 4     5               0.9    0.0           0.05         10                 3
# 5     6               0.8    0.0           0.05          8                 1
# 6     7               0.8    0.0           0.10         10                 3
# 7     8               0.9    0.0           0.05         10                 1
#
#    n_estimators  reg_alpha  reg_lambda  subsample
# 0          2000        0.3         0.8        0.9
# 1          1000        0.0         0.5        0.8
# 2          1500        0.0         0.5        0.9
# 3          2000        0.3         0.8        0.9
# 4          2000        0.3         0.5        0.9
# 5          1000        0.0         0.8        0.9
# 6          1500        0.3         0.5        0.8
# 7          2000        0.3         0.8        0.8

# %% [markdown]
# # XGB - 성능 좋게 나온 파라미터로 다시 돌리기

# %%
best_params = df_params.loc[[0,4, 7],'colsample_bytree	gamma	learning_rate	max_depth	min_child_weight	n_estimators	reg_alpha	reg_lambda	subsample'.split()]
best_params
# Out:
#    colsample_bytree  gamma  learning_rate  max_depth  min_child_weight  \
# 0               0.8    0.0           0.05         12                 3
# 4               0.9    0.0           0.05         10                 3
# 7               0.9    0.0           0.05         10                 1
#
#    n_estimators  reg_alpha  reg_lambda  subsample
# 0          2000        0.3         0.8        0.9
# 4          2000        0.3         0.5        0.9
# 7          2000        0.3         0.8        0.8

# %%
param_grid = {
    'n_estimators': [2000, 2500, 3000],
    'learning_rate': [0.01, 0.05, 0.1],
    'max_depth': [10, 12, 14, 16],
    'subsample': [.9, 1,0],
    'colsample_bytree': [0.8, 0.9],
    'reg_alpha': [0.3, 0.4, 0.5],
    'reg_lambda': [0.5, 0.8, 1.0],
    'min_child_weight': [1, 3],
    'gamma': [0],
}

# %%
import os
import time
import gc
import numpy as np
import pandas as pd
import joblib
import random
from tqdm import tqdm
from itertools import product
from sklearn.preprocessing import MinMaxScaler
from sklearn.metrics import mean_squared_error, r2_score
from xgboost import XGBRegressor

def evaluate_model(name, model, line, X_train, y_train, X_val, y_val):
    t0 = time.time()
    model.fit(X_train, y_train, eval_set=[(X_val, y_val)], verbose=False)
    y_pred = model.predict(X_val)
    elapsed = time.time() - t0

    rmse = np.sqrt(mean_squared_error(y_val, y_pred))
    r2 = r2_score(y_val, y_pred)

    return {'Model': name, 'Line': line, 'Time(s)': elapsed, 'RMSE': rmse, 'R2': r2}


results = []
final_results = []

for line in df['Line'].unique():
    print(f"\n📘 [Line {line}] 모델 학습 중...")

    df_line = df[df['Line'] == line].copy()
    test_line = test[test['Line'] == line].copy()

    for col in ['STN', 'address']:
        df_line[col] = df_line[col].astype('category')
        test_line[col] = test_line[col].astype('category')

    df_line = df_line.sort_values('TM')

    X = df_line[feature_cols]
    y = df_line[target_col].astype(int)
    X_test = test_line[feature_cols]

    X_enc = pd.get_dummies(X, columns=cat_cols, drop_first=False)
    X_test_enc = pd.get_dummies(X_test, columns=cat_cols, drop_first=False)

    X_enc = X_enc.loc[:, ~X_enc.columns.duplicated()]
    X_test_enc = X_test_enc.loc[:, ~X_test_enc.columns.duplicated()]
    X_test_enc = X_test_enc.reindex(columns=X_enc.columns, fill_value=0)

    mm = MinMaxScaler()
    X_scaled = mm.fit_transform(X_enc).astype(np.float32)
    X_test_scaled = mm.transform(X_test_enc).astype(np.float32)

    split_idx = int(len(X_scaled) * 0.8)
    X_train = X_scaled[:split_idx]
    X_val = X_scaled[split_idx:]
    y_train = y.values[:split_idx]
    y_val = y.values[split_idx:]

    # ✅ 수동 랜덤서치 (교차검증 없이 val set으로 평가)
    best_model = None
    best_rmse = float('inf')

    
        # ✅ 단일 모델 학습 (더 이상 반복 없음)
    best_model = XGBRegressor(
        n_estimators=2000,
        learning_rate=0.05,
        max_depth=12,
        subsample=0.9,
        colsample_bytree=0.8,
        reg_alpha=0.3,
        reg_lambda=0.8,
        min_child_weight=3,
        gamma=0,
        tree_method='hist',
        eval_metric='rmse',
        early_stopping_rounds=30,
        random_state=42,
        verbosity=0
    )

    best_model.fit(X_train, y_train, eval_set=[(X_val, y_val)], verbose=100)

    # 평가
    res = evaluate_model('XGB', best_model, line, X_train, y_train, X_val, y_val)
    results.append(res)
    print('✅ XGB 결과:', res)
    #print('🧪 파라미터:', best_model.get_params())

    # 예측
    y_pred = np.round(best_model.predict(X_test_scaled)).astype(int)
    y_pred = np.where(y_pred < 0, 0, y_pred)
    temp = test_line[['hour', 'Line', 'station_number']].copy()
    temp['예측혼잡도'] = y_pred
    final_results.append(temp)

    os.makedirs('./models', exist_ok=True)
    joblib.dump(best_model, f"./models/best_parmas1_xgb_line{line}.pkl", compress=3)

    del df_line, test_line, X, y, X_test
    del X_enc, X_test_enc, X_scaled, X_test_scaled
    del X_train, X_val, y_train, y_val, best_model, y_pred, temp
    gc.collect()

# 결과 저장
final_df = pd.concat(final_results)
output_df = final_df[['예측혼잡도']].rename(columns={'예측혼잡도': 'Congestion'})
os.makedirs('./test', exist_ok=True)
output_df.to_csv('./test/250206-xgb-best1.csv', index=False, encoding='utf-8')

results_df = pd.DataFrame(results)
print("\n📊 전체 성능 요약:")
print(results_df)
# Out:
# 📘 [Line 1] 모델 학습 중...
# [0]	validation_0-rmse:20.27514
# [100]	validation_0-rmse:5.05032
# [200]	validation_0-rmse:4.43756
# [300]	validation_0-rmse:4.18801
# [400]	validation_0-rmse:4.12169
# [500]	validation_0-rmse:4.08802
# [600]	validation_0-rmse:4.06709
# [700]	validation_0-rmse:4.05029
# [800]	validation_0-rmse:4.04292
# [830]	validation_0-rmse:4.04401
# ✅ XGB 결과: {'Model': 'XGB', 'Line': 1, 'Time(s)': 691.4284400939941, 'RMSE': 4.042833518966586, 'R2': 0.9611398723725793}
#
# 📘 [Line 2] 모델 학습 중...
# [0]	validation_0-rmse:21.42276
# [100]	validation_0-rmse:9.27319
# [200]	validation_0-rmse:8.67868
# [300]	validation_0-rmse:8.50251
# [400]	validation_0-rmse:8.44496
# [500]	validation_0-rmse:8.40827
# [600]	validation_0-rmse:8.39077
# [700]	validation_0-rmse:8.38064
# [716]	validation_0-rmse:8.38215
# ✅ XGB 결과: {'Model': 'XGB', 'Line': 2, 'Time(s)': 471.73917841911316, 'RMSE': 8.378386346861745, 'R2': 0.8467743023797729}
#
# 📘 [Line 3] 모델 학습 중...
# [0]	validation_0-rmse:19.34543
# [100]	validation_0-rmse:4.71453
# [200]	validation_0-rmse:4.28603
# [300]	validation_0-rmse:4.27049
# [364]	validation_0-rmse:4.26459
# ✅ XGB 결과: {'Model': 'XGB', 'Line': 3, 'Time(s)': 260.49604082107544, 'RMSE': 4.260000550286424, 'R2': 0.953898552160386}
#
# 📘 [Line 4] 모델 학습 중...
# [0]	validation_0-rmse:20.81097
# [100]	validation_0-rmse:5.01032
# [200]	validation_0-rmse:4.42505
# [300]	validation_0-rmse:4.18252
# [400]	validation_0-rmse:4.08819
# [500]	validation_0-rmse:4.04075
# [600]	validation_0-rmse:4.02227
# [700]	validation_0-rmse:4.01213
# [800]	validation_0-rmse:4.00456
# [900]	validation_0-rmse:4.00107
# [1000]	validation_0-rmse:3.99677
# [1100]	validation_0-rmse:3.99641
# [1118]	validation_0-rmse:3.99587
# ✅ XGB 결과: {'Model': 'XGB', 'Line': 4, 'Time(s)': 816.0972096920013, 'RMSE': 3.9954134984846426, 'R2': 0.964268203579197}
#
# 📘 [Line 5] 모델 학습 중...
# [0]	validation_0-rmse:19.42084
# [100]	validation_0-rmse:5.64517
# [200]	validation_0-rmse:4.67666
# [300]	validation_0-rmse:4.38276
# [400]	validation_0-rmse:4.28757
# [500]	validation_0-rmse:4.25346
# [600]	validation_0-rmse:4.23544
# [700]	validation_0-rmse:4.21588
# [800]	validation_0-rmse:4.20643
# [819]	validation_0-rmse:4.20520
# ✅ XGB 결과: {'Model': 'XGB', 'Line': 5, 'Time(s)': 583.3358232975006, 'RMSE': 4.204847552157288, 'R2': 0.9530994096281233}
#
# 📘 [Line 6] 모델 학습 중...
# [0]	validation_0-rmse:15.73662
# [100]	validation_0-rmse:5.96736
# [200]	validation_0-rmse:5.45987
# [300]	validation_0-rmse:5.39625
# [400]	validation_0-rmse:5.37596
# [500]	validation_0-rmse:5.36593
# [585]	validation_0-rmse:5.36216
# ✅ XGB 결과: {'Model': 'XGB', 'Line': 6, 'Time(s)': 363.892874956131, 'RMSE': 5.3604027481205385, 'R2': 0.8840681723951177}
#
# 📘 [Line 7] 모델 학습 중...
# [0]	validation_0-rmse:23.08596
# [100]	validation_0-rmse:6.74840
# [200]	validation_0-rmse:6.12034
# [300]	validation_0-rmse:5.95352
# [400]	validation_0-rmse:5.89865
# [461]	validation_0-rmse:5.88721
# ✅ XGB 결과: {'Model': 'XGB', 'Line': 7, 'Time(s)': 378.61418771743774, 'RMSE': 5.886850015404509, 'R2': 0.9337420325712585}
#
# 📘 [Line 8] 모델 학습 중...
# [0]	validation_0-rmse:22.72243
# [100]	validation_0-rmse:4.45967
# [200]	validation_0-rmse:4.13730
# [300]	validation_0-rmse:4.10325
# [384]	validation_0-rmse:4.09436
# ✅ XGB 결과: {'Model': 'XGB', 'Line': 8, 'Time(s)': 129.1012098789215, 'RMSE': 4.091825478218226, 'R2': 0.9696636868246408}
#
# 📊 전체 성능 요약:
#   Model  Line     Time(s)      RMSE        R2
# 0   XGB     1  691.428440  4.042834  0.961140
# 1   XGB     2  471.739178  8.378386  0.846774
# 2   XGB     3  260.496041  4.260001  0.953899
# 3   XGB     4  816.097210  3.995413  0.964268
# 4   XGB     5  583.335823  4.204848  0.953099
# 5   XGB     6  363.892875  5.360403  0.884068
# 6   XGB     7  378.614188  5.886850  0.933742
# 7   XGB     8  129.101210  4.091825  0.969664

# %%
gap = pd.read_csv('./test/250206-xgb-best1.csv') # 내 데터터
gap.shape

import os
제출 = pd.read_csv('./test/minjeong.csv') # 민정언니 데이터

import numpy as np

# 마스크 생성
from sklearn.metrics import root_mean_squared_error
rmse = mean_squared_error(
    제출['Congestion'],
    gap['Congestion'],
    squared=False      # squared=False 하면 RMSE 를 직접 계산해 줌
)

print(f"RMSE: {rmse:.4f}")
# Out:
# RMSE: 4.5445

# %% [markdown]
# # LGBM

# %%
import os
import time
import gc
import numpy as np
import pandas as pd
import joblib
from tqdm import tqdm
from sklearn.preprocessing import MinMaxScaler
from sklearn.metrics import mean_squared_error, r2_score
from lightgbm import LGBMRegressor  # ✅ LightGBM으로 변경

def evaluate_model(name, model, line, X_train, y_train, X_val, y_val):
    t0 = time.time()
    model.fit(X_train, y_train)
    y_pred = model.predict(X_val)
    elapsed = time.time() - t0

    rmse = np.sqrt(mean_squared_error(y_val, y_pred))
    r2 = r2_score(y_val, y_pred)

    return {'Model': name, 'Line': line, 'Time(s)': elapsed, 'RMSE': rmse, 'R2': r2}

results = []
final_results = []

for line in df['Line'].unique():
    print(f"\n📘 [Line {line}] 모델 학습 중...")

    df_line = df[df['Line'] == line].copy()
    test_line = test[test['Line'] == line].copy()

    for col in ['STN', 'address']:
        df_line[col] = df_line[col].astype('category')
        test_line[col] = test_line[col].astype('category')

    df_line = df_line.sort_values('TM')

    X = df_line[feature_cols]
    y = df_line[target_col].astype(int)
    X_test = test_line[feature_cols]

    X_enc = pd.get_dummies(X, columns=cat_cols, drop_first=False)
    X_test_enc = pd.get_dummies(X_test, columns=cat_cols, drop_first=False)

    X_enc = X_enc.loc[:, ~X_enc.columns.duplicated()]
    X_test_enc = X_test_enc.loc[:, ~X_test_enc.columns.duplicated()]
    X_test_enc = X_test_enc.reindex(columns=X_enc.columns, fill_value=0)

    mm = MinMaxScaler()
    X_scaled = mm.fit_transform(X_enc).astype(np.float32)
    X_test_scaled = mm.transform(X_test_enc).astype(np.float32)

    split_idx = int(len(X_scaled) * 0.8)
    X_train = X_scaled[:split_idx]
    X_val = X_scaled[split_idx:]
    y_train = y.values[:split_idx]
    y_val = y.values[split_idx:]

    # ✅ LightGBM 모델 정의
    model = LGBMRegressor(
                            n_estimators=1500,
                            learning_rate=0.01,
                            max_depth=12,
                            subsample=0.9,
                            colsample_bytree=0.9,
                            reg_alpha=0.3,
                            reg_lambda=0.8,
                            min_child_samples=20,
                            random_state=42
                        )

    res = evaluate_model('LGBM', model, line, X_train, y_train, X_val, y_val)
    results.append(res)
    print('✅ LGBM 결과:', res)

    y_pred = np.round(model.predict(X_test_scaled)).astype(int)
    y_pred = np.where(y_pred < 0, 0, y_pred)
    temp = test_line[['hour', 'Line', 'station_number']].copy()
    temp['예측혼잡도'] = y_pred
    final_results.append(temp)

    os.makedirs('./models', exist_ok=True)
    joblib.dump(model, f"./models/lgbm_line{line}.pkl", compress=3)

    del df_line, test_line, X, y, X_test
    del X_enc, X_test_enc, X_scaled, X_test_scaled
    del X_train, X_val, y_train, y_val, model, y_pred, temp
    gc.collect()

final_df = pd.concat(final_results)
output_df = final_df[['예측혼잡도']].rename(columns={'예측혼잡도': 'Congestion'})
os.makedirs('./test', exist_ok=True)
output_df.to_csv('./test/250206-lgbm.csv', index=False, encoding='utf-8')

results_df = pd.DataFrame(results)
print("\n📊 전체 성능 요약:")
print(results_df)
# Out:
# 📘 [Line 1] 모델 학습 중...
# [LightGBM] [Info] Auto-choosing col-wise multi-threading, the overhead of testing was 0.302261 seconds.
# You can set `force_col_wise=true` to remove the overhead.
# [LightGBM] [Info] Total Bins 2518
# [LightGBM] [Info] Number of data points in the train set: 2251468, number of used features: 113
# [LightGBM] [Info] Start training from score 18.002817
# ✅ LGBM 결과: {'Model': 'LGBM', 'Line': 1, 'Time(s)': 193.3726589679718, 'RMSE': 7.496302841802039, 'R2': 0.8663937564784803}
#
# 📘 [Line 2] 모델 학습 중...
# [LightGBM] [Info] Auto-choosing col-wise multi-threading, the overhead of testing was 0.218242 seconds.
# You can set `force_col_wise=true` to remove the overhead.
# [LightGBM] [Info] Total Bins 2448
# [LightGBM] [Info] Number of data points in the train set: 1596672, number of used features: 96
# [LightGBM] [Info] Start training from score 28.565433
# ✅ LGBM 결과: {'Model': 'LGBM', 'Line': 2, 'Time(s)': 137.63949418067932, 'RMSE': 9.388149707343784, 'R2': 0.8076151564277432}
#
# 📘 [Line 3] 모델 학습 중...
# [LightGBM] [Info] Auto-choosing col-wise multi-threading, the overhead of testing was 0.227144 seconds.
# You can set `force_col_wise=true` to remove the overhead.
# [LightGBM] [Info] Total Bins 2460
# [LightGBM] [Info] Number of data points in the train set: 1598990, number of used features: 94
# [LightGBM] [Info] Start training from score 19.906141
# ✅ LGBM 결과: {'Model': 'LGBM', 'Line': 3, 'Time(s)': 147.3285026550293, 'RMSE': 5.324485438019154, 'R2': 0.9279804270764774}
#
# 📘 [Line 4] 모델 학습 중...
# [LightGBM] [Info] Auto-choosing col-wise multi-threading, the overhead of testing was 0.247931 seconds.
# You can set `force_col_wise=true` to remove the overhead.
# [LightGBM] [Info] Total Bins 2444
# [LightGBM] [Info] Number of data points in the train set: 1806940, number of used features: 101
# [LightGBM] [Info] Start training from score 18.892067
# ✅ LGBM 결과: {'Model': 'LGBM', 'Line': 4, 'Time(s)': 152.19362473487854, 'RMSE': 7.735369408869891, 'R2': 0.8660491004058612}
#
# 📘 [Line 5] 모델 학습 중...
# [LightGBM] [Info] Auto-choosing row-wise multi-threading, the overhead of testing was 0.105146 seconds.
# You can set `force_row_wise=true` to remove the overhead.
# And if memory is not enough, you can set `force_col_wise=true`.
# [LightGBM] [Info] Total Bins 2489
# [LightGBM] [Info] Number of data points in the train set: 1770249, number of used features: 101
# [LightGBM] [Info] Start training from score 20.651826
# ✅ LGBM 결과: {'Model': 'LGBM', 'Line': 5, 'Time(s)': 96.08661794662476, 'RMSE': 7.033137740212398, 'R2': 0.8687872476503637}
#
# 📘 [Line 6] 모델 학습 중...
# [LightGBM] [Info] Auto-choosing col-wise multi-threading, the overhead of testing was 0.199438 seconds.
# You can set `force_col_wise=true` to remove the overhead.
# [LightGBM] [Info] Total Bins 2393
# [LightGBM] [Info] Number of data points in the train set: 1451520, number of used features: 90
# [LightGBM] [Info] Start training from score 15.109336
# ✅ LGBM 결과: {'Model': 'LGBM', 'Line': 6, 'Time(s)': 125.98094177246094, 'RMSE': 6.254573632432255, 'R2': 0.8421650200948373}
#
# 📘 [Line 7] 모델 학습 중...
# [LightGBM] [Info] Auto-choosing col-wise multi-threading, the overhead of testing was 0.289227 seconds.
# You can set `force_col_wise=true` to remove the overhead.
# [LightGBM] [Info] Total Bins 2436
# [LightGBM] [Info] Number of data points in the train set: 1978368, number of used features: 114
# [LightGBM] [Info] Start training from score 23.131690
# ✅ LGBM 결과: {'Model': 'LGBM', 'Line': 7, 'Time(s)': 165.56231713294983, 'RMSE': 9.136943328207701, 'R2': 0.8403848797608348}
#
# 📘 [Line 8] 모델 학습 중...
# [LightGBM] [Info] Auto-choosing row-wise multi-threading, the overhead of testing was 0.037096 seconds.
# You can set `force_row_wise=true` to remove the overhead.
# And if memory is not enough, you can set `force_col_wise=true`.
# [LightGBM] [Info] Total Bins 2307
# [LightGBM] [Info] Number of data points in the train set: 641256, number of used features: 61
# [LightGBM] [Info] Start training from score 21.157085
# ✅ LGBM 결과: {'Model': 'LGBM', 'Line': 8, 'Time(s)': 36.373398303985596, 'RMSE': 5.776166843011343, 'R2': 0.9395483647667134}
#
# 📊 전체 성능 요약:
#   Model  Line     Time(s)      RMSE        R2
# 0  LGBM     1  193.372659  7.496303  0.866394
# 1  LGBM     2  137.639494  9.388150  0.807615
# 2  LGBM     3  147.328503  5.324485  0.927980
# 3  LGBM     4  152.193625  7.735369  0.866049
# 4  LGBM     5   96.086618  7.033138  0.868787
# 5  LGBM     6  125.980942  6.254574  0.842165
# 6  LGBM     7  165.562317  9.136943  0.840385
# 7  LGBM     8   36.373398  5.776167  0.939548

# %%
gap = pd.read_csv('./test/250206-lgbm.csv') # 내 데터터
gap.shape

import os
제출 = pd.read_csv('./test/minjeong.csv') # 민정언니 데이터

import numpy as np

# 마스크 생성
from sklearn.metrics import root_mean_squared_error
rmse = mean_squared_error(
    제출['Congestion'],
    gap['Congestion'],
    squared=False      # squared=False 하면 RMSE 를 직접 계산해 줌
)

print(f"RMSE: {rmse:.4f}")
# Out:
# RMSE: 7.4661
